# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9511101304657719, score: 30
# Scores: (min: 30, avg: 30, max: 30)
#
# Run: 2, exploration: 0.8866535105013078, score: 15
# Scores: (min: 15, avg: 22.5, max: 30)
#
# Run: 3, exploration: 0.851801859600347, score: 9
# Scores: (min: 9, avg: 18, max: 30)
#
# Run: 4, exploration: 0.8142285204175609, score: 10
# Scores: (min: 9, avg: 16, max: 30)
#
# Run: 5, exploration: 0.7666961448653229, score: 13
# Scores: (min: 9, avg: 15.4, max: 30)
#
# Run: 6, exploration: 0.7292124703704616, score: 11
# Scores: (min: 9, avg: 14.666666666666666, max: 30)
#
# Run: 7, exploration: 0.6900935609921609, score: 12
# Scores: (min: 9, avg: 14.285714285714286, max: 30)
#
# Run: 8, exploration: 0.6596532430440636, score: 10
# Scores: (min: 9, avg: 13.75, max: 30)
#
# Run: 9, exploration: 0.6305556603555866, score: 10
# Scores: (min: 9, avg: 13.333333333333334, max: 30)
#
# Run: 10, exploration: 0.6057704364907278, score: 9
# Scores: (min: 9, avg: 12.9, max: 30)
#
# Run: 11, exploration: 0.5732736268885887, score: 12
# Scores: (min: 9, avg: 12.818181818181818, max: 30)
#
# Run: 12, exploration: 0.5425201222922789, score: 12
# Scores: (min: 9, avg: 12.75, max: 30)
#
# Run: 13, exploration: 0.510849320360386, score: 13
# Scores: (min: 9, avg: 12.76923076923077, max: 30)
#
# Run: 14, exploration: 0.45522245551230495, score: 24
# Scores: (min: 9, avg: 13.571428571428571, max: 30)
#
# Run: 15, exploration: 0.4036245882390106, score: 25
# Scores: (min: 9, avg: 14.333333333333334, max: 30)
#
# Run: 16, exploration: 0.38389143477919885, score: 11
# Scores: (min: 9, avg: 14.125, max: 30)
#
# Run: 17, exploration: 0.36880183088056995, score: 9
# Scores: (min: 9, avg: 13.823529411764707, max: 30)
#
# Run: 18, exploration: 0.35253382661792404, score: 10
# Scores: (min: 9, avg: 13.61111111111111, max: 30)
#
# Run: 19, exploration: 0.33698341088258443, score: 10
# Scores: (min: 9, avg: 13.421052631578947, max: 30)
#
# Run: 20, exploration: 0.22007483514733558, score: 86
# Scores: (min: 9, avg: 17.05, max: 86)
#
# Run: 21, exploration: 0.1865228530605915, score: 34
# Scores: (min: 9, avg: 17.857142857142858, max: 86)
#
# Run: 22, exploration: 0.16209824418995536, score: 29
# Scores: (min: 9, avg: 18.363636363636363, max: 86)
#
# Run: 23, exploration: 0.14811319969530845, score: 19
# Scores: (min: 9, avg: 18.391304347826086, max: 86)
#
# Run: 24, exploration: 0.12807462877562611, score: 30
# Scores: (min: 9, avg: 18.875, max: 86)
#
# Run: 25, exploration: 0.1135578192100607, score: 25
# Scores: (min: 9, avg: 19.12, max: 86)
#
# Run: 26, exploration: 0.07955285615946175, score: 72
# Scores: (min: 9, avg: 21.153846153846153, max: 86)
#
# Run: 27, exploration: 0.0712465030521374, score: 23
# Scores: (min: 9, avg: 21.22222222222222, max: 86)
#
# Run: 28, exploration: 0.05685938874076987, score: 46
# Scores: (min: 9, avg: 22.107142857142858, max: 86)
#
# Run: 29, exploration: 0.04892091923449087, score: 31
# Scores: (min: 9, avg: 22.413793103448278, max: 86)
#
# Run: 30, exploration: 0.04023414326483323, score: 40
# Scores: (min: 9, avg: 23, max: 86)
#
# Run: 31, exploration: 0.03769595998025326, score: 14
# Scores: (min: 9, avg: 22.70967741935484, max: 86)
#
# Run: 32, exploration: 0.030693125720441184, score: 42
# Scores: (min: 9, avg: 23.3125, max: 86)
#
# Run: 33, exploration: 0.028901347193857643, score: 13
# Scores: (min: 9, avg: 23, max: 86)
#
# Run: 34, exploration: 0.026807992814067, score: 16
# Scores: (min: 9, avg: 22.794117647058822, max: 86)
#
# Run: 35, exploration: 0.022158551474944856, score: 39
# Scores: (min: 9, avg: 23.257142857142856, max: 86)
#
# Run: 36, exploration: 0.018500023224111744, score: 37
# Scores: (min: 9, avg: 23.63888888888889, max: 86)
#
# Run: 37, exploration: 0.014255172347583332, score: 53
# Scores: (min: 9, avg: 24.43243243243243, max: 86)
#
# Run: 38, exploration: 0.011433732442257729, score: 45
# Scores: (min: 9, avg: 24.973684210526315, max: 86)
#
# Run: 39, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 25.05128205128205, max: 86)
#
# Run: 40, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 25.85, max: 86)
#
# Run: 41, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 28.853658536585368, max: 149)
#
# Run: 42, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 29.38095238095238, max: 149)
#
# Run: 43, exploration: 0.01, score: 78
# Scores: (min: 9, avg: 30.511627906976745, max: 149)
#
# Run: 44, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 32.54545454545455, max: 149)
#
# Run: 45, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 34.955555555555556, max: 149)
#
# Run: 46, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 38.08695652173913, max: 179)
#
# Run: 47, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 41.51063829787234, max: 199)
#
# Run: 48, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 43.604166666666664, max: 199)
#
# Run: 49, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 46.95918367346939, max: 208)
#
# Run: 50, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 48.64, max: 208)
#
# Run: 51, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 50.11764705882353, max: 208)
#
# Run: 52, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 53.32692307692308, max: 217)
#
# Run: 53, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 55.698113207547166, max: 217)
#
# Run: 54, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 58, max: 217)
#
# Run: 55, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 59.61818181818182, max: 217)
#
# Run: 56, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 61.285714285714285, max: 217)
#
# Run: 57, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 62.45614035087719, max: 217)
#
# Run: 58, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 64.17241379310344, max: 217)
#
# Run: 59, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 65.64406779661017, max: 217)
#
# Run: 60, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 67.05, max: 217)
#
# Run: 61, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 68.1311475409836, max: 217)
#
# Run: 62, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 69.83870967741936, max: 217)
#
# Run: 63, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 70.88888888888889, max: 217)
#
# Run: 64, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 71.953125, max: 217)
#
# Run: 65, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 73.13846153846154, max: 217)
#
# Run: 66, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 74.25757575757575, max: 217)
#
# Run: 67, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 75.34328358208955, max: 217)
#
# Run: 68, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 76.01470588235294, max: 217)
#
# Run: 69, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 77.33333333333333, max: 217)
#
# Run: 70, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 78.08571428571429, max: 217)
#
# Run: 71, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 79.45070422535211, max: 217)
#
# Run: 72, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 80.45833333333333, max: 217)
#
# Run: 73, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 81.46575342465754, max: 217)
#
# Run: 74, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 82.79729729729729, max: 217)
#
# Run: 75, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 83.70666666666666, max: 217)
#
# Run: 76, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 84.90789473684211, max: 217)
#
# Run: 77, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 85.54545454545455, max: 217)
#
# Run: 78, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 86.21794871794872, max: 217)
#
# Run: 79, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 87.69620253164557, max: 217)
#
# Run: 80, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 88.65, max: 217)
#
# Run: 81, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 89.49382716049382, max: 217)
#
# Run: 82, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 90.32926829268293, max: 217)
#
# Run: 83, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 91.13253012048193, max: 217)
#
# Run: 84, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 91.66666666666667, max: 217)
#
# Run: 85, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 92.87058823529412, max: 217)
#
# Run: 86, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 93.53488372093024, max: 217)
#
# Run: 87, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 94.26436781609195, max: 217)
#
# Run: 88, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 95.1590909090909, max: 217)
# Run: 89, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 95.86516853932584, max: 217)
#
# Run: 90, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 96.62222222222222, max: 217)
#
# Run: 91, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 97.8021978021978, max: 217)
#
# Run: 92, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 98.18478260869566, max: 217)
#
# Run: 93, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 99.21505376344086, max: 217)
#
# Run: 94, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 99.82978723404256, max: 217)
#
# Run: 95, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 100.3578947368421, max: 217)
#
# Run: 96, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 100.65625, max: 217)
#
# Run: 97, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 100.36082474226804, max: 217)
#
# Run: 98, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 100.44897959183673, max: 217)
#
# Run: 99, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 100.85858585858585, max: 217)
#
# Run: 100, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 101.05, max: 217)
#
# Run: 101, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 101.88, max: 217)
#
# Run: 102, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 102.62, max: 217)
#
# Run: 103, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 104.08, max: 217)
#
# Run: 104, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 105.63, max: 217)
#
# Run: 105, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 106.91, max: 217)
#
# Run: 106, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 109.5, max: 270)
#
# Run: 107, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 110.82, max: 270)
#
# Run: 108, exploration: 0.01, score: 186
# Scores: (min: 9, avg: 112.58, max: 270)
#
# Run: 109, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 113.68, max: 270)
#
# Run: 110, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 115.19, max: 270)
#
# Run: 111, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 116.4, max: 270)
#
# Run: 112, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 118.58, max: 270)
#
# Run: 113, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 120.13, max: 270)
#
# Run: 114, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 122.02, max: 270)
#
# Run: 115, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 123.55, max: 270)
#
# Run: 116, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 125.01, max: 270)
#
# Run: 117, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 126.34, max: 270)
#
# Run: 118, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 127.84, max: 270)
#
# Run: 119, exploration: 0.01, score: 128
# Scores: (min: 13, avg: 129.02, max: 270)
#
# Run: 120, exploration: 0.01, score: 71
# Scores: (min: 13, avg: 128.87, max: 270)
#
# Run: 121, exploration: 0.01, score: 124
# Scores: (min: 13, avg: 129.77, max: 270)
#
# Run: 122, exploration: 0.01, score: 163
# Scores: (min: 13, avg: 131.11, max: 270)
#
# Run: 123, exploration: 0.01, score: 156
# Scores: (min: 13, avg: 132.48, max: 270)
#
# Run: 124, exploration: 0.01, score: 134
# Scores: (min: 13, avg: 133.52, max: 270)
#
# Run: 125, exploration: 0.01, score: 161
# Scores: (min: 13, avg: 134.88, max: 270)
#
# Run: 126, exploration: 0.01, score: 148
# Scores: (min: 13, avg: 135.64, max: 270)
#
# Run: 127, exploration: 0.01, score: 160
# Scores: (min: 13, avg: 137.01, max: 270)
#
# Run: 128, exploration: 0.01, score: 148
# Scores: (min: 13, avg: 138.03, max: 270)
#
# Run: 129, exploration: 0.01, score: 153
# Scores: (min: 13, avg: 139.25, max: 270)
#
# Run: 130, exploration: 0.01, score: 142
# Scores: (min: 13, avg: 140.27, max: 270)
#
# Run: 131, exploration: 0.01, score: 269
# Scores: (min: 13, avg: 142.82, max: 270)
#
# Run: 132, exploration: 0.01, score: 134
# Scores: (min: 13, avg: 143.74, max: 270)
#
# Run: 133, exploration: 0.01, score: 129
# Scores: (min: 16, avg: 144.9, max: 270)
#
# Run: 134, exploration: 0.01, score: 176
# Scores: (min: 28, avg: 146.5, max: 270)
#
# Run: 135, exploration: 0.01, score: 161
# Scores: (min: 28, avg: 147.72, max: 270)
#
# Run: 136, exploration: 0.01, score: 201
# Scores: (min: 28, avg: 149.36, max: 270)
#
# Run: 137, exploration: 0.01, score: 147
# Scores: (min: 28, avg: 150.3, max: 270)
#
# Run: 138, exploration: 0.01, score: 159
# Scores: (min: 28, avg: 151.44, max: 270)
#
# Run: 139, exploration: 0.01, score: 123
# Scores: (min: 51, avg: 152.39, max: 270)
#
# Run: 140, exploration: 0.01, score: 117
# Scores: (min: 51, avg: 152.99, max: 270)
#
# Run: 141, exploration: 0.01, score: 157
# Scores: (min: 51, avg: 153.07, max: 270)
#
# Run: 142, exploration: 0.01, score: 194
# Scores: (min: 71, avg: 154.5, max: 270)
#
# Run: 143, exploration: 0.01, score: 133
# Scores: (min: 71, avg: 155.05, max: 270)
#
# Run: 144, exploration: 0.01, score: 123
# Scores: (min: 71, avg: 155.08, max: 270)
#
# Run: 145, exploration: 0.01, score: 143
# Scores: (min: 71, avg: 155.1, max: 270)
#
# Run: 146, exploration: 0.01, score: 117
# Scores: (min: 71, avg: 154.48, max: 270)
#
# Run: 147, exploration: 0.01, score: 119
# Scores: (min: 71, avg: 153.68, max: 270)
#
# Run: 148, exploration: 0.01, score: 39
# Scores: (min: 39, avg: 152.65, max: 270)
#
# Run: 149, exploration: 0.01, score: 29
# Scores: (min: 29, avg: 150.86, max: 270)
#
# Run: 150, exploration: 0.01, score: 97
# Scores: (min: 29, avg: 150.52, max: 270)
#
# Run: 151, exploration: 0.01, score: 51
# Scores: (min: 29, avg: 149.79, max: 270)
#
# Run: 152, exploration: 0.01, score: 102
# Scores: (min: 29, avg: 148.64, max: 270)
#
# Run: 153, exploration: 0.01, score: 112
# Scores: (min: 29, avg: 147.97, max: 270)
#
# Run: 154, exploration: 0.01, score: 118
# Scores: (min: 29, avg: 147.35, max: 270)
#
# Run: 155, exploration: 0.01, score: 104
# Scores: (min: 29, avg: 146.92, max: 270)
#
# Run: 156, exploration: 0.01, score: 83
# Scores: (min: 29, avg: 146.22, max: 270)
#
# Run: 157, exploration: 0.01, score: 164
# Scores: (min: 29, avg: 146.58, max: 270)
#
# Run: 158, exploration: 0.01, score: 115
# Scores: (min: 29, avg: 146.11, max: 270)
#
# Run: 159, exploration: 0.01, score: 19
# Scores: (min: 19, avg: 144.79, max: 270)
#
# Run: 160, exploration: 0.01, score: 119
# Scores: (min: 19, avg: 144.48, max: 270)
#
# Run: 161, exploration: 0.01, score: 124
# Scores: (min: 19, avg: 144.39, max: 270)
#
# Run: 162, exploration: 0.01, score: 94
# Scores: (min: 19, avg: 143.59, max: 270)
#
# Run: 163, exploration: 0.01, score: 100
# Scores: (min: 19, avg: 143.23, max: 270)
#
# Run: 164, exploration: 0.01, score: 125
# Scores: (min: 19, avg: 143.09, max: 270)
#
# Run: 165, exploration: 0.01, score: 131
# Scores: (min: 19, avg: 142.91, max: 270)
#
# Run: 166, exploration: 0.01, score: 164
# Scores: (min: 19, avg: 143.08, max: 270)
#
# Run: 167, exploration: 0.01, score: 132
# Scores: (min: 19, avg: 142.93, max: 270)
#
# Run: 168, exploration: 0.01, score: 133
# Scores: (min: 19, avg: 143.05, max: 270)
#
# Run: 169, exploration: 0.01, score: 124
# Scores: (min: 19, avg: 142.62, max: 270)
#
# Run: 170, exploration: 0.01, score: 132
# Scores: (min: 19, avg: 142.64, max: 270)
#
# Run: 171, exploration: 0.01, score: 104
# Scores: (min: 19, avg: 141.93, max: 270)
#
# Run: 172, exploration: 0.01, score: 187
# Scores: (min: 19, avg: 142.28, max: 270)
#
# Run: 173, exploration: 0.01, score: 113
# Scores: (min: 19, avg: 141.87, max: 270)
#
# Run: 174, exploration: 0.01, score: 94
# Scores: (min: 19, avg: 141.01, max: 270)
#
# Run: 175, exploration: 0.01, score: 140
# Scores: (min: 19, avg: 140.9, max: 270)
#
# Run: 176, exploration: 0.01, score: 112
# Scores: (min: 19, avg: 140.27, max: 270)
#
# Run: 177, exploration: 0.01, score: 139
# Scores: (min: 19, avg: 140.32, max: 270)
#
# Run: 178, exploration: 0.01, score: 167
# Scores: (min: 19, avg: 140.61, max: 270)
#
# Run: 179, exploration: 0.01, score: 144
# Scores: (min: 19, avg: 140.02, max: 270)
#
# Run: 180, exploration: 0.01, score: 156
# Scores: (min: 19, avg: 139.94, max: 270)
#
# Run: 181, exploration: 0.01, score: 148
# Scores: (min: 19, avg: 139.85, max: 270)
#
# Run: 182, exploration: 0.01, score: 153
# Scores: (min: 19, avg: 139.8, max: 270)
#
# Run: 183, exploration: 0.01, score: 145
# Scores: (min: 19, avg: 139.68, max: 270)
#
# Run: 184, exploration: 0.01, score: 38
# Scores: (min: 19, avg: 138.7, max: 270)
#
# Run: 185, exploration: 0.01, score: 94
# Scores: (min: 19, avg: 137.7, max: 270)
#
# Run: 186, exploration: 0.01, score: 96
# Scores: (min: 19, avg: 137.16, max: 270)
#
# Run: 187, exploration: 0.01, score: 133
# Scores: (min: 19, avg: 136.92, max: 270)
#
# Run: 188, exploration: 0.01, score: 241
# Scores: (min: 19, avg: 137.6, max: 270)
# Run: 189, exploration: 0.01, score: 115
# Scores: (min: 19, avg: 137.17, max: 270)
#
# Run: 190, exploration: 0.01, score: 96
# Scores: (min: 19, avg: 136.49, max: 270)
#
# Run: 191, exploration: 0.01, score: 145
# Scores: (min: 19, avg: 135.9, max: 270)
#
# Run: 192, exploration: 0.01, score: 204
# Scores: (min: 19, avg: 136.61, max: 270)
#
# Run: 193, exploration: 0.01, score: 202
# Scores: (min: 19, avg: 136.69, max: 270)
#
# Run: 194, exploration: 0.01, score: 129
# Scores: (min: 19, avg: 136.41, max: 270)
#
# Run: 195, exploration: 0.01, score: 208
# Scores: (min: 19, avg: 136.99, max: 270)
#
# Run: 196, exploration: 0.01, score: 156
# Scores: (min: 19, avg: 137.26, max: 270)
#
# Run: 197, exploration: 0.01, score: 159
# Scores: (min: 19, avg: 138.13, max: 270)
#
# Run: 198, exploration: 0.01, score: 168
# Scores: (min: 19, avg: 138.72, max: 270)
#
# Run: 199, exploration: 0.01, score: 154
# Scores: (min: 19, avg: 138.85, max: 270)
#
# Run: 200, exploration: 0.01, score: 165
# Scores: (min: 19, avg: 139.3, max: 270)
#
# Run: 201, exploration: 0.01, score: 152
# Scores: (min: 19, avg: 139.69, max: 270)
#
# Run: 202, exploration: 0.01, score: 204
# Scores: (min: 19, avg: 140.84, max: 270)
#
# Run: 203, exploration: 0.01, score: 126
# Scores: (min: 19, avg: 140.55, max: 270)
#
# Run: 204, exploration: 0.01, score: 130
# Scores: (min: 19, avg: 140.2, max: 270)
#
# Run: 205, exploration: 0.01, score: 79
# Scores: (min: 19, avg: 139.58, max: 270)
#
# Run: 206, exploration: 0.01, score: 164
# Scores: (min: 19, avg: 138.52, max: 269)
#
# Run: 207, exploration: 0.01, score: 239
# Scores: (min: 19, avg: 139.47, max: 269)
#
# Run: 208, exploration: 0.01, score: 118
# Scores: (min: 19, avg: 138.79, max: 269)
#
# Run: 209, exploration: 0.01, score: 119
# Scores: (min: 19, avg: 138.78, max: 269)
#
# Run: 210, exploration: 0.01, score: 143
# Scores: (min: 19, avg: 138.61, max: 269)
#
# Run: 211, exploration: 0.01, score: 138
# Scores: (min: 19, avg: 138.66, max: 269)
#
# Run: 212, exploration: 0.01, score: 160
# Scores: (min: 19, avg: 137.96, max: 269)
#
# Run: 213, exploration: 0.01, score: 160
# Scores: (min: 19, avg: 137.88, max: 269)
#
# Run: 214, exploration: 0.01, score: 120
# Scores: (min: 19, avg: 136.95, max: 269)
#
# Run: 215, exploration: 0.01, score: 164
# Scores: (min: 19, avg: 136.81, max: 269)
#
# Run: 216, exploration: 0.01, score: 262
# Scores: (min: 19, avg: 137.86, max: 269)
#
# Run: 217, exploration: 0.01, score: 107
# Scores: (min: 19, avg: 137.51, max: 269)
#
# Run: 218, exploration: 0.01, score: 139
# Scores: (min: 19, avg: 137.3, max: 269)
#
# Run: 219, exploration: 0.01, score: 98
# Scores: (min: 19, avg: 137, max: 269)
#
# Run: 220, exploration: 0.01, score: 17
# Scores: (min: 17, avg: 136.46, max: 269)
#
# Run: 221, exploration: 0.01, score: 92
# Scores: (min: 17, avg: 136.14, max: 269)
#
# Run: 222, exploration: 0.01, score: 100
# Scores: (min: 17, avg: 135.51, max: 269)
#
# Run: 223, exploration: 0.01, score: 137
# Scores: (min: 17, avg: 135.32, max: 269)
#
# Run: 224, exploration: 0.01, score: 97
# Scores: (min: 17, avg: 134.95, max: 269)
#
# Run: 225, exploration: 0.01, score: 243
# Scores: (min: 17, avg: 135.77, max: 269)
#
# Run: 226, exploration: 0.01, score: 158
# Scores: (min: 17, avg: 135.87, max: 269)
#
# Run: 227, exploration: 0.01, score: 65
# Scores: (min: 17, avg: 134.92, max: 269)
#
# Run: 228, exploration: 0.01, score: 207
# Scores: (min: 17, avg: 135.51, max: 269)
#
# Run: 229, exploration: 0.01, score: 127
# Scores: (min: 17, avg: 135.25, max: 269)
#
# Run: 230, exploration: 0.01, score: 174
# Scores: (min: 17, avg: 135.57, max: 269)
#
# Run: 231, exploration: 0.01, score: 155
# Scores: (min: 17, avg: 134.43, max: 262)
#
# Run: 232, exploration: 0.01, score: 183
# Scores: (min: 17, avg: 134.92, max: 262)
#
# Run: 233, exploration: 0.01, score: 310
# Scores: (min: 17, avg: 136.73, max: 310)
#
# Run: 234, exploration: 0.01, score: 153
# Scores: (min: 17, avg: 136.5, max: 310)
#
# Run: 235, exploration: 0.01, score: 171
# Scores: (min: 17, avg: 136.6, max: 310)
#
# Run: 236, exploration: 0.01, score: 124
# Scores: (min: 17, avg: 135.83, max: 310)
#
# Run: 237, exploration: 0.01, score: 392
# Scores: (min: 17, avg: 138.28, max: 392)
#
# Run: 238, exploration: 0.01, score: 184
# Scores: (min: 17, avg: 138.53, max: 392)
#
# Run: 239, exploration: 0.01, score: 272
# Scores: (min: 17, avg: 140.02, max: 392)
#
# Run: 240, exploration: 0.01, score: 159
# Scores: (min: 17, avg: 140.44, max: 392)
#
# Run: 241, exploration: 0.01, score: 152
# Scores: (min: 17, avg: 140.39, max: 392)
#
# Run: 242, exploration: 0.01, score: 215
# Scores: (min: 17, avg: 140.6, max: 392)
#
# Run: 243, exploration: 0.01, score: 45
# Scores: (min: 17, avg: 139.72, max: 392)
#
# Run: 244, exploration: 0.01, score: 159
# Scores: (min: 17, avg: 140.08, max: 392)
#
# Run: 245, exploration: 0.01, score: 121
# Scores: (min: 17, avg: 139.86, max: 392)
#
# Run: 246, exploration: 0.01, score: 108
# Scores: (min: 17, avg: 139.77, max: 392)
#
# Run: 247, exploration: 0.01, score: 95
# Scores: (min: 17, avg: 139.53, max: 392)
#
# Run: 248, exploration: 0.01, score: 155
# Scores: (min: 17, avg: 140.69, max: 392)
#
# Run: 249, exploration: 0.01, score: 68
# Scores: (min: 17, avg: 141.08, max: 392)
#
# Run: 250, exploration: 0.01, score: 169
# Scores: (min: 17, avg: 141.8, max: 392)
#
# Run: 251, exploration: 0.01, score: 112
# Scores: (min: 17, avg: 142.41, max: 392)
#
# Run: 252, exploration: 0.01, score: 19
# Scores: (min: 17, avg: 141.58, max: 392)
#
# Run: 253, exploration: 0.01, score: 186
# Scores: (min: 17, avg: 142.32, max: 392)
#
# Run: 254, exploration: 0.01, score: 257
# Scores: (min: 17, avg: 143.71, max: 392)
#
# Run: 255, exploration: 0.01, score: 141
# Scores: (min: 17, avg: 144.08, max: 392)
#
# Run: 256, exploration: 0.01, score: 149
# Scores: (min: 17, avg: 144.74, max: 392)
#
# Run: 257, exploration: 0.01, score: 325
# Scores: (min: 17, avg: 146.35, max: 392)
#
# Run: 258, exploration: 0.01, score: 137
# Scores: (min: 17, avg: 146.57, max: 392)
#
# Run: 259, exploration: 0.01, score: 172
# Scores: (min: 17, avg: 148.1, max: 392)
#
# Run: 260, exploration: 0.01, score: 258
# Scores: (min: 17, avg: 149.49, max: 392)
#
# Run: 261, exploration: 0.01, score: 369
# Scores: (min: 17, avg: 151.94, max: 392)
#
# Run: 262, exploration: 0.01, score: 169
# Scores: (min: 17, avg: 152.69, max: 392)
#
# Run: 263, exploration: 0.01, score: 193
# Scores: (min: 17, avg: 153.62, max: 392)
#
# Run: 264, exploration: 0.01, score: 166
# Scores: (min: 17, avg: 154.03, max: 392)
#
# Run: 265, exploration: 0.01, score: 162
# Scores: (min: 17, avg: 154.34, max: 392)
#
# Run: 266, exploration: 0.01, score: 124
# Scores: (min: 17, avg: 153.94, max: 392)
#
# Run: 267, exploration: 0.01, score: 155
# Scores: (min: 17, avg: 154.17, max: 392)
#
# Run: 268, exploration: 0.01, score: 107
# Scores: (min: 17, avg: 153.91, max: 392)
#
# Run: 269, exploration: 0.01, score: 319
# Scores: (min: 17, avg: 155.86, max: 392)
#
# Run: 270, exploration: 0.01, score: 252
# Scores: (min: 17, avg: 157.06, max: 392)
#
# Run: 271, exploration: 0.01, score: 134
# Scores: (min: 17, avg: 157.36, max: 392)
#
# Run: 272, exploration: 0.01, score: 121
# Scores: (min: 17, avg: 156.7, max: 392)
#
# Run: 273, exploration: 0.01, score: 160
# Scores: (min: 17, avg: 157.17, max: 392)
#
# Run: 274, exploration: 0.01, score: 148
# Scores: (min: 17, avg: 157.71, max: 392)
#
# Run: 275, exploration: 0.01, score: 281
# Scores: (min: 17, avg: 159.12, max: 392)
#
# Run: 276, exploration: 0.01, score: 349
# Scores: (min: 17, avg: 161.49, max: 392)
#
# Run: 277, exploration: 0.01, score: 139
# Scores: (min: 17, avg: 161.49, max: 392)
#
# Run: 278, exploration: 0.01, score: 112
# Scores: (min: 17, avg: 160.94, max: 392)
#
# Run: 279, exploration: 0.01, score: 151
# Scores: (min: 17, avg: 161.01, max: 392)
#
# Run: 280, exploration: 0.01, score: 144
# Scores: (min: 17, avg: 160.89, max: 392)
#
# Run: 281, exploration: 0.01, score: 442
# Scores: (min: 17, avg: 163.83, max: 442)
#
# Run: 282, exploration: 0.01, score: 165
# Scores: (min: 17, avg: 163.95, max: 442)
#
# Run: 283, exploration: 0.01, score: 242
# Scores: (min: 17, avg: 164.92, max: 442)
#
# Run: 284, exploration: 0.01, score: 256
# Scores: (min: 17, avg: 167.1, max: 442)
#
# Run: 285, exploration: 0.01, score: 57
# Scores: (min: 17, avg: 166.73, max: 442)
#
# Run: 286, exploration: 0.01, score: 119
# Scores: (min: 17, avg: 166.96, max: 442)
#
# Run: 287, exploration: 0.01, score: 131
# Scores: (min: 17, avg: 166.94, max: 442)
#
# Run: 288, exploration: 0.01, score: 142
# Scores: (min: 17, avg: 165.95, max: 442)
#
# Run: 289, exploration: 0.01, score: 164
# Scores: (min: 17, avg: 166.44, max: 442)
# Run: 290, exploration: 0.01, score: 94
# Scores: (min: 17, avg: 166.42, max: 442)
#
# Run: 291, exploration: 0.01, score: 29
# Scores: (min: 17, avg: 165.26, max: 442)
#
# Run: 292, exploration: 0.01, score: 123
# Scores: (min: 17, avg: 164.45, max: 442)
#
# Run: 293, exploration: 0.01, score: 84
# Scores: (min: 17, avg: 163.27, max: 442)
#
# Run: 294, exploration: 0.01, score: 153
# Scores: (min: 17, avg: 163.51, max: 442)
#
# Run: 295, exploration: 0.01, score: 316
# Scores: (min: 17, avg: 164.59, max: 442)
#
# Run: 296, exploration: 0.01, score: 141
# Scores: (min: 17, avg: 164.44, max: 442)
#
# Run: 297, exploration: 0.01, score: 240
# Scores: (min: 17, avg: 165.25, max: 442)
#
# Run: 298, exploration: 0.01, score: 159
# Scores: (min: 17, avg: 165.16, max: 442)
#
# Run: 299, exploration: 0.01, score: 158
# Scores: (min: 17, avg: 165.2, max: 442)
#
# Run: 300, exploration: 0.01, score: 337
# Scores: (min: 17, avg: 166.92, max: 442)
#
# Run: 301, exploration: 0.01, score: 277
# Scores: (min: 17, avg: 168.17, max: 442)
#
# Run: 302, exploration: 0.01, score: 123
# Scores: (min: 17, avg: 167.36, max: 442)
#
# Run: 303, exploration: 0.01, score: 134
# Scores: (min: 17, avg: 167.44, max: 442)
#
# Run: 304, exploration: 0.01, score: 114
# Scores: (min: 17, avg: 167.28, max: 442)
#
# Run: 305, exploration: 0.01, score: 163
# Scores: (min: 17, avg: 168.12, max: 442)
#
# Run: 306, exploration: 0.01, score: 135
# Scores: (min: 17, avg: 167.83, max: 442)
#
# Run: 307, exploration: 0.01, score: 107
# Scores: (min: 17, avg: 166.51, max: 442)
#
# Run: 308, exploration: 0.01, score: 174
# Scores: (min: 17, avg: 167.07, max: 442)
#
# Run: 309, exploration: 0.01, score: 282
# Scores: (min: 17, avg: 168.7, max: 442)
#
# Run: 310, exploration: 0.01, score: 181
# Scores: (min: 17, avg: 169.08, max: 442)
#
# Run: 311, exploration: 0.01, score: 135
# Scores: (min: 17, avg: 169.05, max: 442)
#
# Run: 312, exploration: 0.01, score: 424
# Scores: (min: 17, avg: 171.69, max: 442)
#
# Run: 313, exploration: 0.01, score: 153
# Scores: (min: 17, avg: 171.62, max: 442)
#
# Run: 314, exploration: 0.01, score: 131
# Scores: (min: 17, avg: 171.73, max: 442)
#
# Run: 315, exploration: 0.01, score: 131
# Scores: (min: 17, avg: 171.4, max: 442)
#
# Run: 316, exploration: 0.01, score: 195
# Scores: (min: 17, avg: 170.73, max: 442)
#
# Run: 317, exploration: 0.01, score: 155
# Scores: (min: 17, avg: 171.21, max: 442)
#
# Run: 318, exploration: 0.01, score: 237
# Scores: (min: 17, avg: 172.19, max: 442)
#
# Run: 319, exploration: 0.01, score: 175
# Scores: (min: 17, avg: 172.96, max: 442)
#
# Run: 320, exploration: 0.01, score: 192
# Scores: (min: 19, avg: 174.71, max: 442)
#
# Run: 321, exploration: 0.01, score: 327
# Scores: (min: 19, avg: 177.06, max: 442)
#
# Run: 322, exploration: 0.01, score: 126
# Scores: (min: 19, avg: 177.32, max: 442)
#
# Run: 323, exploration: 0.01, score: 128
# Scores: (min: 19, avg: 177.23, max: 442)
#
# Run: 324, exploration: 0.01, score: 100
# Scores: (min: 19, avg: 177.26, max: 442)
#
# Run: 325, exploration: 0.01, score: 51
# Scores: (min: 19, avg: 175.34, max: 442)
#
# Run: 326, exploration: 0.01, score: 63
# Scores: (min: 19, avg: 174.39, max: 442)
#
# Run: 327, exploration: 0.01, score: 38
# Scores: (min: 19, avg: 174.12, max: 442)
#
# Run: 328, exploration: 0.01, score: 153
# Scores: (min: 19, avg: 173.58, max: 442)
#
# Run: 329, exploration: 0.01, score: 89
# Scores: (min: 19, avg: 173.2, max: 442)
#
# Run: 330, exploration: 0.01, score: 311
# Scores: (min: 19, avg: 174.57, max: 442)
#
# Run: 331, exploration: 0.01, score: 118
# Scores: (min: 19, avg: 174.2, max: 442)
#
# Run: 332, exploration: 0.01, score: 155
# Scores: (min: 19, avg: 173.92, max: 442)
#
# Run: 333, exploration: 0.01, score: 159
# Scores: (min: 19, avg: 172.41, max: 442)
#
# Run: 334, exploration: 0.01, score: 189
# Scores: (min: 19, avg: 172.77, max: 442)
#
# Run: 335, exploration: 0.01, score: 207
# Scores: (min: 19, avg: 173.13, max: 442)
#
# Run: 336, exploration: 0.01, score: 137
# Scores: (min: 19, avg: 173.26, max: 442)
#
# Run: 337, exploration: 0.01, score: 285
# Scores: (min: 19, avg: 172.19, max: 442)
#
# Run: 338, exploration: 0.01, score: 129
# Scores: (min: 19, avg: 171.64, max: 442)
#
# Run: 339, exploration: 0.01, score: 149
# Scores: (min: 19, avg: 170.41, max: 442)
#
# Run: 340, exploration: 0.01, score: 127
# Scores: (min: 19, avg: 170.09, max: 442)
#
# Run: 341, exploration: 0.01, score: 479
# Scores: (min: 19, avg: 173.36, max: 479)
#
# Run: 342, exploration: 0.01, score: 123
# Scores: (min: 19, avg: 172.44, max: 479)
#
# Run: 343, exploration: 0.01, score: 137
# Scores: (min: 19, avg: 173.36, max: 479)
#
# Run: 344, exploration: 0.01, score: 117
# Scores: (min: 19, avg: 172.94, max: 479)
#
# Run: 345, exploration: 0.01, score: 161
# Scores: (min: 19, avg: 173.34, max: 479)
#
# Run: 346, exploration: 0.01, score: 281
# Scores: (min: 19, avg: 175.07, max: 479)
#
# Run: 347, exploration: 0.01, score: 140
# Scores: (min: 19, avg: 175.52, max: 479)
#
# Run: 348, exploration: 0.01, score: 317
# Scores: (min: 19, avg: 177.14, max: 479)
#
# Run: 349, exploration: 0.01, score: 292
# Scores: (min: 19, avg: 179.38, max: 479)
#
# Run: 350, exploration: 0.01, score: 137
# Scores: (min: 19, avg: 179.06, max: 479)
#
# Run: 351, exploration: 0.01, score: 117
# Scores: (min: 19, avg: 179.11, max: 479)
#
# Run: 352, exploration: 0.01, score: 198
# Scores: (min: 29, avg: 180.9, max: 479)
#
# Run: 353, exploration: 0.01, score: 469
# Scores: (min: 29, avg: 183.73, max: 479)
#
# Run: 354, exploration: 0.01, score: 243
# Scores: (min: 29, avg: 183.59, max: 479)
#
# Run: 355, exploration: 0.01, score: 153
# Scores: (min: 29, avg: 183.71, max: 479)
#
# Run: 356, exploration: 0.01, score: 105
# Scores: (min: 29, avg: 183.27, max: 479)
#
# Run: 357, exploration: 0.01, score: 147
# Scores: (min: 29, avg: 181.49, max: 479)
#
# Run: 358, exploration: 0.01, score: 242
# Scores: (min: 29, avg: 182.54, max: 479)
#
# Run: 359, exploration: 0.01, score: 90
# Scores: (min: 29, avg: 181.72, max: 479)
#
# Run: 360, exploration: 0.01, score: 185
# Scores: (min: 29, avg: 180.99, max: 479)
#
# Run: 361, exploration: 0.01, score: 164
# Scores: (min: 29, avg: 178.94, max: 479)
#
# Run: 362, exploration: 0.01, score: 342
# Scores: (min: 29, avg: 180.67, max: 479)
#
# Run: 363, exploration: 0.01, score: 186
# Scores: (min: 29, avg: 180.6, max: 479)
#
# Run: 364, exploration: 0.01, score: 131
# Scores: (min: 29, avg: 180.25, max: 479)
#
# Run: 365, exploration: 0.01, score: 144
# Scores: (min: 29, avg: 180.07, max: 479)
#
# Run: 366, exploration: 0.01, score: 13
# Scores: (min: 13, avg: 178.96, max: 479)
#
# Run: 367, exploration: 0.01, score: 26
# Scores: (min: 13, avg: 177.67, max: 479)
#
# Run: 368, exploration: 0.01, score: 15
# Scores: (min: 13, avg: 176.75, max: 479)
#
# Run: 369, exploration: 0.01, score: 87
# Scores: (min: 13, avg: 174.43, max: 479)
#
# Run: 370, exploration: 0.01, score: 15
# Scores: (min: 13, avg: 172.06, max: 479)
#
# Run: 371, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 170.81, max: 479)
#
# Run: 372, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 170.68, max: 479)
#
# Run: 373, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 170.37, max: 479)
#
# Run: 374, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 169.49, max: 479)
#
# Run: 375, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 166.9, max: 479)
#
# Run: 376, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 163.61, max: 479)
#
# Run: 377, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 162.42, max: 479)
#
# Run: 378, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 161.42, max: 479)
#
# Run: 379, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 160.37, max: 479)
#
# Run: 380, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 159.11, max: 479)
#
# Run: 381, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 156.12, max: 479)
#
# Run: 382, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 156.25, max: 479)
#
# Run: 383, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 154.43, max: 479)
#
# Run: 384, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 153.01, max: 479)
#
# Run: 385, exploration: 0.01, score: 385
# Scores: (min: 9, avg: 156.29, max: 479)
#
# Run: 386, exploration: 0.01, score: 256
# Scores: (min: 9, avg: 157.66, max: 479)
#
# Run: 387, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 157.86, max: 479)
#
# Run: 388, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 157.89, max: 479)
#
# Run: 389, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 157.53, max: 479)
#
# Run: 390, exploration: 0.01, score: 321
# Scores: (min: 9, avg: 159.8, max: 479)
# Run: 391, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 160.95, max: 479)
#
# Run: 392, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 161.16, max: 479)
#
# Run: 393, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 162.1, max: 479)
#
# Run: 394, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 165.57, max: 500)
#
# Run: 395, exploration: 0.01, score: 192
# Scores: (min: 9, avg: 164.33, max: 500)
#
# Run: 396, exploration: 0.01, score: 382
# Scores: (min: 9, avg: 166.74, max: 500)
#
# Run: 397, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 165.96, max: 500)
#
# Run: 398, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 164.77, max: 500)
#
# Run: 399, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 164.11, max: 500)
#
# Run: 400, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 161.84, max: 500)
#
# Run: 401, exploration: 0.01, score: 214
# Scores: (min: 9, avg: 161.21, max: 500)
#
# Run: 402, exploration: 0.01, score: 231
# Scores: (min: 9, avg: 162.29, max: 500)
#
# Run: 403, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 165.95, max: 500)
#
# Run: 404, exploration: 0.01, score: 257
# Scores: (min: 9, avg: 167.38, max: 500)
#
# Run: 405, exploration: 0.01, score: 276
# Scores: (min: 9, avg: 168.51, max: 500)
#
# Run: 406, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 168.58, max: 500)
#
# Run: 407, exploration: 0.01, score: 340
# Scores: (min: 9, avg: 170.91, max: 500)
#
# Run: 408, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 171.07, max: 500)
#
# Run: 409, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 169.63, max: 500)
#
# Run: 410, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 168.96, max: 500)
#
# Run: 411, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 168.58, max: 500)
#
# Run: 412, exploration: 0.01, score: 219
# Scores: (min: 9, avg: 166.53, max: 500)
#
# Run: 413, exploration: 0.01, score: 379
# Scores: (min: 9, avg: 168.79, max: 500)
#
# Run: 414, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 169.32, max: 500)
#
# Run: 415, exploration: 0.01, score: 215
# Scores: (min: 9, avg: 170.16, max: 500)
#
# Run: 416, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 169.44, max: 500)
#
# Run: 417, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 169.78, max: 500)
#
# Run: 418, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 168.76, max: 500)
#
# Run: 419, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 168.35, max: 500)
#
# Run: 420, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 168.66, max: 500)
#
# Run: 421, exploration: 0.01, score: 391
# Scores: (min: 9, avg: 169.3, max: 500)
#
# Run: 422, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 170.39, max: 500)
#
# Run: 423, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 170.41, max: 500)
#
# Run: 424, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 170.83, max: 500)
#
# Run: 425, exploration: 0.01, score: 87
# Scores: (min: 9, avg: 171.19, max: 500)
#
# Run: 426, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 171.73, max: 500)
#
# Run: 427, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 173.38, max: 500)
#
# Run: 428, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 173.04, max: 500)
#
# Run: 429, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 173.98, max: 500)
#
# Run: 430, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 171.79, max: 500)
#
# Run: 431, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 172.07, max: 500)
#
# Run: 432, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 171.8, max: 500)
#
# Run: 433, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 171.66, max: 500)
#
# Run: 434, exploration: 0.01, score: 210
# Scores: (min: 9, avg: 171.87, max: 500)
#
# Run: 435, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 171.35, max: 500)
#
# Run: 436, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 171.48, max: 500)
#
# Run: 437, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 169.18, max: 500)
#
# Run: 438, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 168.18, max: 500)
#
# Run: 439, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 166.78, max: 500)
#
# Run: 440, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 165.6, max: 500)
#
# Run: 441, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 160.9, max: 500)
#
# Run: 442, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 159.77, max: 500)
#
# Run: 443, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 158.51, max: 500)
#
# Run: 444, exploration: 0.01, score: 76
# Scores: (min: 9, avg: 158.1, max: 500)
#
# Run: 445, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 157.19, max: 500)
#
# Run: 446, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 154.52, max: 500)
#
# Run: 447, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 153.3, max: 500)
#
# Run: 448, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 150.29, max: 500)
#
# Run: 449, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 147.52, max: 500)
#
# Run: 450, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 146.25, max: 500)
#
# Run: 451, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 145.23, max: 500)
#
# Run: 452, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 143.34, max: 500)
#
# Run: 453, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 139.78, max: 500)
#
# Run: 454, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 139.58, max: 500)
#
# Run: 455, exploration: 0.01, score: 246
# Scores: (min: 9, avg: 140.51, max: 500)
#
# Run: 456, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 141.4, max: 500)
#
# Run: 457, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 141.45, max: 500)
#
# Run: 458, exploration: 0.01, score: 468
# Scores: (min: 9, avg: 143.71, max: 500)
#
# Run: 459, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 144.2, max: 500)
#
# Run: 460, exploration: 0.01, score: 334
# Scores: (min: 9, avg: 145.69, max: 500)
#
# Run: 461, exploration: 0.01, score: 245
# Scores: (min: 9, avg: 146.5, max: 500)
#
# Run: 462, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 144.54, max: 500)
#
# Run: 463, exploration: 0.01, score: 347
# Scores: (min: 9, avg: 146.15, max: 500)
#
# Run: 464, exploration: 0.01, score: 211
# Scores: (min: 9, avg: 146.95, max: 500)
#
# Run: 465, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 146.93, max: 500)
#
# Run: 466, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 148.55, max: 500)
#
# Run: 467, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 150.91, max: 500)
#
# Run: 468, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 152.35, max: 500)
#
# Run: 469, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 156.48, max: 500)
#
# Run: 470, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 157.76, max: 500)
#
# Run: 471, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 159.27, max: 500)
#
# Run: 472, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 159.62, max: 500)
#
# Run: 473, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 159.56, max: 500)
#
# Run: 474, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 163.96, max: 500)
#
# Run: 475, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 165.32, max: 500)
#
# Run: 476, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 166.6, max: 500)
#
# Run: 477, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 168.48, max: 500)
#
# Run: 478, exploration: 0.01, score: 334
# Scores: (min: 9, avg: 171.7, max: 500)
#
# Run: 479, exploration: 0.01, score: 312
# Scores: (min: 9, avg: 174.36, max: 500)
#
# Run: 480, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 175.56, max: 500)
#
# Run: 481, exploration: 0.01, score: 287
# Scores: (min: 9, avg: 177, max: 500)
#
# Run: 482, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 176.69, max: 500)
#
# Run: 483, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 177.13, max: 500)
#
# Run: 484, exploration: 0.01, score: 417
# Scores: (min: 9, avg: 180.16, max: 500)
#
# Run: 485, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 181.31, max: 500)
#
# Run: 486, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 179.79, max: 500)
#
# Run: 487, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 179.27, max: 500)
#
# Run: 488, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 180.12, max: 500)
#
# Run: 489, exploration: 0.01, score: 323
# Scores: (min: 9, avg: 182.07, max: 500)
#
# Run: 490, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 180.47, max: 500)
#
# Run: 491, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 184.03, max: 500)
#
# Run: 492, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 183.81, max: 500)
# Run: 493, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 183.38, max: 500)
#
# Run: 494, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 179.59, max: 500)
#
# Run: 495, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 179.75, max: 500)
#
# Run: 496, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 176.17, max: 500)
#
# Run: 497, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 174.71, max: 500)
#
# Run: 498, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 174.58, max: 500)
#
# Run: 499, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 175.15, max: 500)
#
# Run: 500, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 175.03, max: 500)
#
# Run: 501, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 173.83, max: 500)
#
# Run: 502, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 176.52, max: 500)
#
# Run: 503, exploration: 0.01, score: 290
# Scores: (min: 9, avg: 174.42, max: 500)
#
# Run: 504, exploration: 0.01, score: 354
# Scores: (min: 9, avg: 175.39, max: 500)
#
# Run: 505, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 173.9, max: 500)
#
# Run: 506, exploration: 0.01, score: 261
# Scores: (min: 9, avg: 175.09, max: 500)
#
# Run: 507, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 173.27, max: 500)
#
# Run: 508, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 173.16, max: 500)
#
# Run: 509, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 173.86, max: 500)
#
# Run: 510, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 173.81, max: 500)
#
# Run: 511, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 175.46, max: 500)
#
# Run: 512, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 174.08, max: 500)
#
# Run: 513, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 170.98, max: 500)
#
# Run: 514, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 170.22, max: 500)
#
# Run: 515, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 169.13, max: 500)
#
# Run: 516, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 168.94, max: 500)
#
# Run: 517, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 168.2, max: 500)
#
# Run: 518, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 167.56, max: 500)
#
# Run: 519, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 167.17, max: 500)
#
# Run: 520, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 165.94, max: 500)
#
# Run: 521, exploration: 0.01, score: 281
# Scores: (min: 9, avg: 164.84, max: 500)
#
# Run: 522, exploration: 0.01, score: 307
# Scores: (min: 9, avg: 165.56, max: 500)
#
# Run: 523, exploration: 0.01, score: 219
# Scores: (min: 9, avg: 166.45, max: 500)
#
# Run: 524, exploration: 0.01, score: 209
# Scores: (min: 9, avg: 167.12, max: 500)
#
# Run: 525, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 168.43, max: 500)
#
# Run: 526, exploration: 0.01, score: 85
# Scores: (min: 9, avg: 168.11, max: 500)
#
# Run: 527, exploration: 0.01, score: 271
# Scores: (min: 9, avg: 168.79, max: 500)
#
# Run: 528, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 169.09, max: 500)
#
# Run: 529, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 169.43, max: 500)
#
# Run: 530, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 170.3, max: 500)
#
# Run: 531, exploration: 0.01, score: 272
# Scores: (min: 9, avg: 171.56, max: 500)
#
# Run: 532, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 171.82, max: 500)
#
# Run: 533, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 172.54, max: 500)
#
# Run: 534, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 172.33, max: 500)
#
# Run: 535, exploration: 0.01, score: 292
# Scores: (min: 9, avg: 173.7, max: 500)
#
# Run: 536, exploration: 0.01, score: 343
# Scores: (min: 9, avg: 175.63, max: 500)
#
# Run: 537, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 176.76, max: 500)
#
# Run: 538, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 177.67, max: 500)
#
# Run: 539, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 178.81, max: 500)
#
# Run: 540, exploration: 0.01, score: 432
# Scores: (min: 9, avg: 183.04, max: 500)
#
# Run: 541, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 185.57, max: 500)
#
# Run: 542, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 186.8, max: 500)
#
# Run: 543, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 188.31, max: 500)
#
# Run: 544, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 189.29, max: 500)
#
# Run: 545, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 193.59, max: 500)
#
# Run: 546, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 194.7, max: 500)
#
# Run: 547, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 194.64, max: 500)
#
# Run: 548, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 194.6, max: 500)
#
# Run: 549, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 195.59, max: 500)
#
# Solved in 449 runs, 549 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.01 #increased value of learning rate  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.946354579813443, score: 31
# Scores: (min: 31, avg: 31, max: 31)
#
# Run: 2, exploration: 0.8911090557802088, score: 13
# Scores: (min: 13, avg: 22, max: 31)
#
# Run: 3, exploration: 0.8307187014821328, score: 15
# Scores: (min: 13, avg: 19.666666666666668, max: 31)
#
# Run: 4, exploration: 0.7666961448653229, score: 17
# Scores: (min: 13, avg: 19, max: 31)
#
# Run: 5, exploration: 0.7111635524897149, score: 16
# Scores: (min: 13, avg: 18.4, max: 31)
#
# Run: 6, exploration: 0.6369088258938781, score: 23
# Scores: (min: 13, avg: 19.166666666666668, max: 31)
#
# Run: 7, exploration: 0.5907768628656763, score: 16
# Scores: (min: 13, avg: 18.714285714285715, max: 31)
#
# Run: 8, exploration: 0.5590843898207511, score: 12
# Scores: (min: 12, avg: 17.875, max: 31)
#
# Run: 9, exploration: 0.5185893309484582, score: 16
# Scores: (min: 12, avg: 17.666666666666668, max: 31)
#
# Run: 10, exploration: 0.4883155414435353, score: 13
# Scores: (min: 12, avg: 17.2, max: 31)
#
# Run: 11, exploration: 0.4598090507939749, score: 13
# Scores: (min: 12, avg: 16.818181818181817, max: 31)
#
# Run: 12, exploration: 0.43952667968844233, score: 10
# Scores: (min: 10, avg: 16.25, max: 31)
#
# Run: 13, exploration: 0.4222502236424958, score: 9
# Scores: (min: 9, avg: 15.692307692307692, max: 31)
#
# Run: 14, exploration: 0.3936343764094253, score: 15
# Scores: (min: 9, avg: 15.642857142857142, max: 31)
#
# Run: 15, exploration: 0.37627099809304654, score: 10
# Scores: (min: 9, avg: 15.266666666666667, max: 31)
#
# Run: 16, exploration: 0.3578751580867638, score: 11
# Scores: (min: 9, avg: 15, max: 31)
#
# Run: 17, exploration: 0.3420891339682016, score: 10
# Scores: (min: 9, avg: 14.705882352941176, max: 31)
#
# Run: 18, exploration: 0.3125753549412418, score: 19
# Scores: (min: 9, avg: 14.944444444444445, max: 31)
#
# Run: 19, exploration: 0.29580711868545667, score: 12
# Scores: (min: 9, avg: 14.789473684210526, max: 31)
#
# Run: 20, exploration: 0.2827589419554058, score: 10
# Scores: (min: 9, avg: 14.55, max: 31)
#
# Run: 21, exploration: 0.2689348941735696, score: 11
# Scores: (min: 9, avg: 14.380952380952381, max: 31)
#
# Run: 22, exploration: 0.25578670228422234, score: 11
# Scores: (min: 9, avg: 14.227272727272727, max: 31)
#
# Run: 23, exploration: 0.21142436319205632, score: 39
# Scores: (min: 9, avg: 15.304347826086957, max: 39)
#
# Run: 24, exploration: 0.18190617987607657, score: 31
# Scores: (min: 9, avg: 15.958333333333334, max: 39)
#
# Run: 25, exploration: 0.16873052768933355, score: 16
# Scores: (min: 9, avg: 15.96, max: 39)
#
# Run: 26, exploration: 0.15111286553822956, score: 23
# Scores: (min: 9, avg: 16.23076923076923, max: 39)
#
# Run: 27, exploration: 0.13669828187021155, score: 21
# Scores: (min: 9, avg: 16.40740740740741, max: 39)
#
# Run: 28, exploration: 0.13001512070402377, score: 11
# Scores: (min: 9, avg: 16.214285714285715, max: 39)
#
# Run: 29, exploration: 0.11130363979080501, score: 32
# Scores: (min: 9, avg: 16.75862068965517, max: 39)
#
# Run: 30, exploration: 0.1042820154910064, score: 14
# Scores: (min: 9, avg: 16.666666666666668, max: 39)
#
# Run: 31, exploration: 0.10018300685223579, score: 9
# Scores: (min: 9, avg: 16.419354838709676, max: 39)
#
# Run: 32, exploration: 0.08619587539414532, score: 31
# Scores: (min: 9, avg: 16.875, max: 39)
#
# Run: 33, exploration: 0.08198177029173696, score: 11
# Scores: (min: 9, avg: 16.696969696969695, max: 39)
#
# Run: 34, exploration: 0.07875931641927113, score: 9
# Scores: (min: 9, avg: 16.470588235294116, max: 39)
#
# Run: 35, exploration: 0.07490878371492794, score: 11
# Scores: (min: 9, avg: 16.314285714285713, max: 39)
#
# Run: 36, exploration: 0.0712465030521374, score: 11
# Scores: (min: 9, avg: 16.166666666666668, max: 39)
#
# Run: 37, exploration: 0.06477420436570952, score: 20
# Scores: (min: 9, avg: 16.27027027027027, max: 39)
#
# Run: 38, exploration: 0.05685938874076987, score: 27
# Scores: (min: 9, avg: 16.55263157894737, max: 39)
#
# Run: 39, exploration: 0.052214913061211746, score: 18
# Scores: (min: 9, avg: 16.58974358974359, max: 39)
#
# Run: 40, exploration: 0.0494138221100385, score: 12
# Scores: (min: 9, avg: 16.475, max: 39)
#
# Run: 41, exploration: 0.043812938841152796, score: 25
# Scores: (min: 9, avg: 16.682926829268293, max: 39)
#
# Run: 42, exploration: 0.040032972548509065, score: 19
# Scores: (min: 9, avg: 16.738095238095237, max: 39)
#
# Run: 43, exploration: 0.03308985827710748, score: 39
# Scores: (min: 9, avg: 17.25581395348837, max: 39)
#
# Run: 44, exploration: 0.030235026982422884, score: 19
# Scores: (min: 9, avg: 17.295454545454547, max: 39)
#
# Run: 45, exploration: 0.026807992814067, score: 25
# Scores: (min: 9, avg: 17.466666666666665, max: 39)
#
# Run: 46, exploration: 0.024991218342344988, score: 15
# Scores: (min: 9, avg: 17.41304347826087, max: 39)
#
# Run: 47, exploration: 0.023181078627322618, score: 16
# Scores: (min: 9, avg: 17.382978723404257, max: 39)
#
# Run: 48, exploration: 0.018500023224111744, score: 46
# Scores: (min: 9, avg: 17.979166666666668, max: 46)
#
# Run: 49, exploration: 0.01575835418494799, score: 33
# Scores: (min: 9, avg: 18.285714285714285, max: 46)
#
# Run: 50, exploration: 0.014987930304771725, score: 11
# Scores: (min: 9, avg: 18.14, max: 46)
#
# Run: 51, exploration: 0.012895378303744804, score: 31
# Scores: (min: 9, avg: 18.392156862745097, max: 46)
#
# Run: 52, exploration: 0.010499784796482848, score: 42
# Scores: (min: 9, avg: 18.846153846153847, max: 46)
#
# Run: 53, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 18.92452830188679, max: 46)
#
# Run: 54, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 18.75925925925926, max: 46)
#
# Run: 55, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 19.272727272727273, max: 47)
#
# Run: 56, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 19.571428571428573, max: 47)
#
# Run: 57, exploration: 0.01, score: 91
# Scores: (min: 9, avg: 20.82456140350877, max: 91)
#
# Run: 58, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 21.25862068965517, max: 91)
#
# Run: 59, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 21.508474576271187, max: 91)
#
# Run: 60, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 21.683333333333334, max: 91)
#
# Run: 61, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 21.688524590163933, max: 91)
#
# Run: 62, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 21.548387096774192, max: 91)
#
# Run: 63, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 21.746031746031747, max: 91)
#
# Run: 64, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 21.546875, max: 91)
#
# Run: 65, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 21.6, max: 91)
#
# Run: 66, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 21.62121212121212, max: 91)
#
# Run: 67, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 21.47761194029851, max: 91)
#
# Run: 68, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 21.61764705882353, max: 91)
#
# Run: 69, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 22.304347826086957, max: 91)
#
# Run: 70, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 22.142857142857142, max: 91)
#
# Run: 71, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 22.098591549295776, max: 91)
#
# Run: 72, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 22.041666666666668, max: 91)
#
# Run: 73, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 21.972602739726028, max: 91)
#
# Run: 74, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 22.16216216216216, max: 91)
#
# Run: 75, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 22.186666666666667, max: 91)
#
# Run: 76, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 22.44736842105263, max: 91)
#
# Run: 77, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 22.571428571428573, max: 91)
#
# Run: 78, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 22.512820512820515, max: 91)
#
# Run: 79, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 22.379746835443036, max: 91)
#
# Run: 80, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 22.7875, max: 91)
#
# Run: 81, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 22.91358024691358, max: 91)
#
# Run: 82, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 22.78048780487805, max: 91)
#
# Run: 83, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 22.746987951807228, max: 91)
#
# Run: 84, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 22.976190476190474, max: 91)
#
# Run: 85, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 23.51764705882353, max: 91)
#
# Run: 86, exploration: 0.01, score: 85
# Scores: (min: 9, avg: 24.232558139534884, max: 91)
# Run: 87, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 24.057471264367816, max: 91)
#
# Run: 88, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 23.90909090909091, max: 91)
#
# Run: 89, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 24.10112359550562, max: 91)
#
# Run: 90, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 24.533333333333335, max: 91)
#
# Run: 91, exploration: 0.01, score: 91
# Scores: (min: 9, avg: 25.263736263736263, max: 91)
#
# Run: 92, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 25.304347826086957, max: 91)
#
# Run: 93, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 25.21505376344086, max: 91)
#
# Run: 94, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 25.48936170212766, max: 91)
#
# Run: 95, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.305263157894736, max: 91)
#
# Run: 96, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.166666666666668, max: 91)
#
# Run: 97, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 25.15463917525773, max: 91)
#
# Run: 98, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25, max: 91)
#
# Run: 99, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 25.262626262626263, max: 91)
#
# Run: 100, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 25.33, max: 91)
#
# Run: 101, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.14, max: 91)
#
# Run: 102, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 25.47, max: 91)
#
# Run: 103, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 25.75, max: 91)
#
# Run: 104, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 25.81, max: 91)
#
# Run: 105, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 25.85, max: 91)
#
# Run: 106, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 25.8, max: 91)
#
# Run: 107, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 25.91, max: 91)
#
# Run: 108, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 25.92, max: 91)
#
# Run: 109, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 26.11, max: 91)
#
# Run: 110, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 27.12, max: 114)
#
# Run: 111, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 27.1, max: 114)
#
# Run: 112, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 27.23, max: 114)
#
# Run: 113, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 28.1, max: 114)
#
# Run: 114, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 28.67, max: 114)
#
# Run: 115, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.67, max: 114)
#
# Run: 116, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.65, max: 114)
#
# Run: 117, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 29.73, max: 118)
#
# Run: 118, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 30.58, max: 118)
#
# Run: 119, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 30.87, max: 118)
#
# Run: 120, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 31.5, max: 118)
#
# Run: 121, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 32.79, max: 140)
#
# Run: 122, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 32.94, max: 140)
#
# Run: 123, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 32.77, max: 140)
#
# Run: 124, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 33.11, max: 140)
#
# Run: 125, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 33.19, max: 140)
#
# Run: 126, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 33.79, max: 140)
#
# Run: 127, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 34.23, max: 140)
#
# Run: 128, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 34.38, max: 140)
#
# Run: 129, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 34.59, max: 140)
#
# Run: 130, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 34.76, max: 140)
#
# Run: 131, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 34.99, max: 140)
#
# Run: 132, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 34.93, max: 140)
#
# Run: 133, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.92, max: 140)
#
# Run: 134, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.93, max: 140)
#
# Run: 135, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.91, max: 140)
#
# Run: 136, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.9, max: 140)
#
# Run: 137, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 34.81, max: 140)
#
# Run: 138, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.64, max: 140)
#
# Run: 139, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.55, max: 140)
#
# Run: 140, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.53, max: 140)
#
# Run: 141, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.38, max: 140)
#
# Run: 142, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.29, max: 140)
#
# Run: 143, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34, max: 140)
#
# Run: 144, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.91, max: 140)
#
# Run: 145, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 34.06, max: 140)
#
# Run: 146, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 34.52, max: 140)
#
# Run: 147, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 34.66, max: 140)
#
# Run: 148, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 35.04, max: 140)
#
# Run: 149, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.8, max: 140)
#
# Run: 150, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 34.85, max: 140)
#
# Run: 151, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 34.87, max: 140)
#
# Run: 152, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 34.58, max: 140)
#
# Run: 153, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 34.6, max: 140)
#
# Run: 154, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 34.79, max: 140)
#
# Run: 155, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 34.69, max: 140)
#
# Run: 156, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 34.45, max: 140)
#
# Run: 157, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 33.76, max: 140)
#
# Run: 158, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 34.28, max: 140)
#
# Run: 159, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 34.37, max: 140)
#
# Run: 160, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 34.66, max: 140)
#
# Run: 161, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 34.63, max: 140)
#
# Run: 162, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 34.66, max: 140)
#
# Run: 163, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 34.78, max: 140)
#
# Run: 164, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 35.19, max: 140)
#
# Run: 165, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 35.57, max: 140)
#
# Run: 166, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 35.93, max: 140)
#
# Run: 167, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 37.45, max: 164)
#
# Run: 168, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 37.66, max: 164)
#
# Run: 169, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 37.05, max: 164)
#
# Run: 170, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 37.03, max: 164)
#
# Run: 171, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 36.92, max: 164)
#
# Run: 172, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.84, max: 164)
#
# Run: 173, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.76, max: 164)
#
# Run: 174, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.5, max: 164)
#
# Run: 175, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.35, max: 164)
#
# Run: 176, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 36.01, max: 164)
#
# Run: 177, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.79, max: 164)
#
# Run: 178, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 35.69, max: 164)
#
# Run: 179, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 35.68, max: 164)
#
# Run: 180, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.22, max: 164)
#
# Run: 181, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.98, max: 164)
#
# Run: 182, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.96, max: 164)
#
# Run: 183, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 34.84, max: 164)
#
# Run: 184, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.51, max: 164)
#
# Run: 185, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.91, max: 164)
#
# Run: 186, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.16, max: 164)
#
# Run: 187, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.17, max: 164)
#
# Run: 188, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 33.14, max: 164)
#
# Run: 189, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.83, max: 164)
# Run: 190, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.3, max: 164)
#
# Run: 191, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.48, max: 164)
#
# Run: 192, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.29, max: 164)
#
# Run: 193, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.22, max: 164)
#
# Run: 194, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.81, max: 164)
#
# Run: 195, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.83, max: 164)
#
# Run: 196, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.79, max: 164)
#
# Run: 197, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.64, max: 164)
#
# Run: 198, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.64, max: 164)
#
# Run: 199, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.22, max: 164)
#
# Run: 200, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30, max: 164)
#
# Run: 201, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.98, max: 164)
#
# Run: 202, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.62, max: 164)
#
# Run: 203, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.28, max: 164)
#
# Run: 204, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.14, max: 164)
#
# Run: 205, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.04, max: 164)
#
# Run: 206, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 28.97, max: 164)
#
# Run: 207, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.79, max: 164)
#
# Run: 208, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 28.77, max: 164)
#
# Run: 209, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 28.5, max: 164)
#
# Run: 210, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.46, max: 164)
#
# Run: 211, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.44, max: 164)
#
# Run: 212, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.31, max: 164)
#
# Run: 213, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 26.43, max: 164)
#
# Run: 214, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.81, max: 164)
#
# Run: 215, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.8, max: 164)
#
# Run: 216, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.81, max: 164)
#
# Run: 217, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 24.74, max: 164)
#
# Run: 218, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.8, max: 164)
#
# Run: 219, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.48, max: 164)
#
# Run: 220, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.84, max: 164)
#
# Run: 221, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 21.52, max: 164)
#
# Run: 222, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.36, max: 164)
#
# Run: 223, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 21.22, max: 164)
#
# Run: 224, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.66, max: 164)
#
# Run: 225, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.51, max: 164)
#
# Run: 226, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.76, max: 164)
#
# Run: 227, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.2, max: 164)
#
# Run: 228, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.07, max: 164)
#
# Run: 229, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.64, max: 164)
#
# Run: 230, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.41, max: 164)
#
# Run: 231, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 18.3, max: 164)
#
# Run: 232, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.15, max: 164)
#
# Run: 233, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.15, max: 164)
#
# Run: 234, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.18, max: 164)
#
# Run: 235, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.19, max: 164)
#
# Run: 236, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.2, max: 164)
#
# Run: 237, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.18, max: 164)
#
# Run: 238, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.19, max: 164)
#
# Run: 239, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.21, max: 164)
#
# Run: 240, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.19, max: 164)
#
# Run: 241, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.19, max: 164)
#
# Run: 242, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.18, max: 164)
#
# Run: 243, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.16, max: 164)
#
# Run: 244, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.16, max: 164)
#
# Run: 245, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.85, max: 164)
#
# Run: 246, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 17.5, max: 164)
#
# Run: 247, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.33, max: 164)
#
# Run: 248, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 16.68, max: 164)
#
# Run: 249, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 16.88, max: 164)
#
# Run: 250, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.82, max: 164)
#
# Run: 251, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.62, max: 164)
#
# Run: 252, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 16.72, max: 164)
#
# Run: 253, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.64, max: 164)
#
# Run: 254, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.56, max: 164)
#
# Run: 255, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.3, max: 164)
#
# Run: 256, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.38, max: 164)
#
# Run: 257, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 16.49, max: 164)
#
# Run: 258, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 16.8, max: 164)
#
# Run: 259, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 17.05, max: 164)
#
# Run: 260, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.66, max: 164)
#
# Run: 261, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.72, max: 164)
#
# Run: 262, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.76, max: 164)
#
# Run: 263, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 16.7, max: 164)
#
# Run: 264, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 16.62, max: 164)
#
# Run: 265, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.13, max: 164)
#
# Run: 266, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 15.93, max: 164)
#
# Run: 267, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.4, max: 129)
#
# Run: 268, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 14.15, max: 129)
#
# Run: 269, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.17, max: 129)
#
# Run: 270, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.26, max: 129)
#
# Run: 271, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 15.16, max: 129)
#
# Run: 272, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 15.46, max: 129)
#
# Run: 273, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.57, max: 129)
#
# Run: 274, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 16.12, max: 129)
#
# Run: 275, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 16.58, max: 129)
#
# Run: 276, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 17.13, max: 129)
#
# Run: 277, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.23, max: 129)
#
# Run: 278, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 17.84, max: 129)
#
# Run: 279, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 18.09, max: 129)
#
# Run: 280, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 18.29, max: 129)
#
# Run: 281, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 18.62, max: 129)
#
# Run: 282, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.63, max: 129)
#
# Run: 283, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 19.2, max: 129)
#
# Run: 284, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 19.55, max: 129)
#
# Run: 285, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 20.34, max: 129)
#
# Run: 286, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 21.1, max: 129)
#
# Run: 287, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 21.72, max: 129)
#
# Run: 288, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 22.09, max: 129)
#
# Run: 289, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 22.59, max: 129)
#
# Run: 290, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 22.69, max: 129)
#
# Run: 291, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 23.34, max: 129)
#
# Run: 292, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.33, max: 129)
#
# Run: 293, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 23.8, max: 129)
#
# Run: 294, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 24.11, max: 129)
# Run: 295, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 24.64, max: 129)
#
# Run: 296, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 26.1, max: 154)
#
# Run: 297, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 26.56, max: 154)
#
# Run: 298, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 27.52, max: 154)
#
# Run: 299, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 28.04, max: 154)
#
# Run: 300, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 28.83, max: 154)
#
# Run: 301, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 29.6, max: 154)
#
# Run: 302, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 30.66, max: 154)
#
# Run: 303, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 30.72, max: 154)
#
# Run: 304, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 31.44, max: 154)
#
# Run: 305, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 32.2, max: 154)
#
# Run: 306, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 33.71, max: 162)
#
# Run: 307, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 34.24, max: 162)
#
# Run: 308, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 34.28, max: 162)
#
# Run: 309, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 34.56, max: 162)
#
# Run: 310, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 34.93, max: 162)
#
# Run: 311, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 35.93, max: 162)
#
# Run: 312, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.92, max: 162)
#
# Run: 313, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.93, max: 162)
#
# Run: 314, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.92, max: 162)
#
# Run: 315, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.93, max: 162)
#
# Run: 316, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 35.91, max: 162)
#
# Run: 317, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.9, max: 162)
#
# Run: 318, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.89, max: 162)
#
# Run: 319, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.9, max: 162)
#
# Run: 320, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.9, max: 162)
#
# Run: 321, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.92, max: 162)
#
# Run: 322, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 36.44, max: 162)
#
# Run: 323, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 37.62, max: 162)
#
# Run: 324, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 38.25, max: 162)
#
# Run: 325, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 40.1, max: 194)
#
# Run: 326, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 40.85, max: 194)
#
# Run: 327, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 40.91, max: 194)
#
# Run: 328, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 41.91, max: 194)
#
# Run: 329, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 42.5, max: 194)
#
# Run: 330, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 43.39, max: 194)
#
# Run: 331, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 43.5, max: 194)
#
# Run: 332, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 44.67, max: 194)
#
# Run: 333, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 44.9, max: 194)
#
# Run: 334, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 44.9, max: 194)
#
# Run: 335, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 45.56, max: 194)
#
# Run: 336, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 46.1, max: 194)
#
# Run: 337, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 46.09, max: 194)
#
# Run: 338, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 46.07, max: 194)
#
# Run: 339, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 46.07, max: 194)
#
# Run: 340, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 46.09, max: 194)
#
# Run: 341, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 46.09, max: 194)
#
# Run: 342, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 46.1, max: 194)
#
# Run: 343, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 46.12, max: 194)
#
# Run: 344, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 46.11, max: 194)
#
# Run: 345, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 46.12, max: 194)
#
# Run: 346, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.95, max: 194)
#
# Run: 347, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.91, max: 194)
#
# Run: 348, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.82, max: 194)
#
# Run: 349, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.62, max: 194)
#
# Run: 350, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.61, max: 194)
#
# Run: 351, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 45.56, max: 194)
#
# Run: 352, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.43, max: 194)
#
# Run: 353, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.35, max: 194)
#
# Run: 354, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.23, max: 194)
#
# Run: 355, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 45.39, max: 194)
#
# Run: 356, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 46.52, max: 194)
#
# Run: 357, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 46.68, max: 194)
#
# Run: 358, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 45.99, max: 194)
#
# Run: 359, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 45.63, max: 194)
#
# Run: 360, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 45.85, max: 194)
#
# Run: 361, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 45.78, max: 194)
#
# Run: 362, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 46.61, max: 194)
#
# Run: 363, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 46.35, max: 194)
#
# Run: 364, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 46.44, max: 194)
#
# Run: 365, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 46.53, max: 194)
#
# Run: 366, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 46.54, max: 194)
#
# Run: 367, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 47.57, max: 194)
#
# Run: 368, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 48.29, max: 194)
#
# Run: 369, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 48.31, max: 194)
#
# Run: 370, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 48.98, max: 194)
#
# Run: 371, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 48.17, max: 194)
#
# Run: 372, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 47.86, max: 194)
#
# Run: 373, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 48.04, max: 194)
#
# Run: 374, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 49.04, max: 194)
#
# Run: 375, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 49.38, max: 194)
#
# Run: 376, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 48.93, max: 194)
#
# Run: 377, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 49.07, max: 194)
#
# Run: 378, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 48.56, max: 194)
#
# Run: 379, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 48.42, max: 194)
#
# Run: 380, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 48.24, max: 194)
#
# Run: 381, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 48.1, max: 194)
#
# Run: 382, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 48.47, max: 194)
#
# Run: 383, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 49.1, max: 194)
#
# Run: 384, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 48.78, max: 194)
#
# Run: 385, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 48.01, max: 194)
#
# Run: 386, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 47.23, max: 194)
#
# Run: 387, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 46.71, max: 194)
#
# Run: 388, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 46.54, max: 194)
#
# Run: 389, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 46.17, max: 194)
#
# Run: 390, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 46.96, max: 194)
#
# Run: 391, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 46.34, max: 194)
#
# Run: 392, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 46.34, max: 194)
#
# Run: 393, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.87, max: 194)
#
# Run: 394, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.55, max: 194)
#
# Run: 395, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.01, max: 194)
#
# Run: 396, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 43.56, max: 194)
#
# Run: 397, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.11, max: 194)
#
# Run: 398, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 42.16, max: 194)
# Run: 399, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 41.63, max: 194)
#
# Run: 400, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.83, max: 194)
#
# Run: 401, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.06, max: 194)
#
# Run: 402, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39, max: 194)
#
# Run: 403, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.94, max: 194)
#
# Run: 404, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.22, max: 194)
#
# Run: 405, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 37.45, max: 194)
#
# Run: 406, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.92, max: 194)
#
# Run: 407, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.39, max: 194)
#
# Run: 408, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.34, max: 194)
#
# Run: 409, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.07, max: 194)
#
# Run: 410, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 34.68, max: 194)
#
# Run: 411, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.69, max: 194)
#
# Run: 412, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.7, max: 194)
#
# Run: 413, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.71, max: 194)
#
# Run: 414, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.71, max: 194)
#
# Run: 415, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.71, max: 194)
#
# Run: 416, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.72, max: 194)
#
# Run: 417, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.72, max: 194)
#
# Run: 418, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 33.71, max: 194)
#
# Run: 419, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 33.72, max: 194)
#
# Run: 420, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.72, max: 194)
#
# Run: 421, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.71, max: 194)
#
# Run: 422, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.19, max: 194)
#
# Run: 423, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.03, max: 194)
#
# Run: 424, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.4, max: 194)
#
# Run: 425, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.56, max: 165)
#
# Run: 426, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.83, max: 165)
#
# Run: 427, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.77, max: 165)
#
# Run: 428, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.74, max: 165)
#
# Run: 429, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.15, max: 165)
#
# Run: 430, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.27, max: 165)
#
# Run: 431, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.05, max: 165)
#
# Run: 432, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.88, max: 165)
#
# Run: 433, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 24.63, max: 165)
#
# Run: 434, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.6, max: 165)
#
# Run: 435, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.93, max: 165)
#
# Run: 436, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.37, max: 165)
#
# Run: 437, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.39, max: 165)
#
# Run: 438, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.39, max: 165)
#
# Run: 439, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.37, max: 165)
#
# Run: 440, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.36, max: 165)
#
# Run: 441, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.35, max: 165)
#
# Run: 442, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 23.33, max: 165)
#
# Run: 443, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.33, max: 165)
#
# Run: 444, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.34, max: 165)
#
# Run: 445, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.33, max: 165)
#
# Run: 446, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.33, max: 165)
#
# Run: 447, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.34, max: 165)
#
# Run: 448, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.34, max: 165)
#
# Run: 449, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.34, max: 165)
#
# Run: 450, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.36, max: 165)
#
# Run: 451, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.38, max: 165)
#
# Run: 452, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.37, max: 165)
#
# Run: 453, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.38, max: 165)
#
# Run: 454, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 23.37, max: 165)
#
# Run: 455, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.2, max: 165)
#
# Run: 456, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.96, max: 165)
#
# Run: 457, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 21.58, max: 165)
#
# Run: 458, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 21.09, max: 165)
#
# Run: 459, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.85, max: 165)
#
# Run: 460, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 20.57, max: 165)
#
# Run: 461, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.5, max: 165)
#
# Run: 462, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.62, max: 165)
#
# Run: 463, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.63, max: 165)
#
# Run: 464, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.24, max: 165)
#
# Run: 465, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.13, max: 165)
#
# Run: 466, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.82, max: 165)
#
# Run: 467, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.88, max: 165)
#
# Run: 468, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17, max: 165)
#
# Run: 469, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 17.14, max: 165)
#
# Run: 470, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.5, max: 165)
#
# Run: 471, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.5, max: 165)
#
# Run: 472, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.55, max: 165)
#
# Run: 473, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.28, max: 165)
#
# Run: 474, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.77, max: 128)
#
# Run: 475, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.99, max: 128)
#
# Run: 476, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 14.23, max: 128)
#
# Run: 477, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 14.11, max: 128)
#
# Run: 478, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.03, max: 128)
#
# Run: 479, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.92, max: 128)
#
# Run: 480, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.91, max: 128)
#
# Run: 481, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.77, max: 128)
#
# Run: 482, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.39, max: 128)
#
# Run: 483, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 12.53, max: 99)
#
# Run: 484, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.56, max: 99)
#
# Run: 485, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.68, max: 99)
#
# Run: 486, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.8, max: 99)
#
# Run: 487, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.7, max: 99)
#
# Run: 488, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.56, max: 99)
#
# Run: 489, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 12.6, max: 99)
#
# Run: 490, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 11.85, max: 42)
#
# Run: 491, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 13.92, max: 219)
#
# Run: 492, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.09, max: 219)
#
# Run: 493, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 14.35, max: 219)
#
# Run: 494, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.37, max: 219)
#
# Run: 495, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.47, max: 219)
#
# Run: 496, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 14.85, max: 219)
#
# Run: 497, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.93, max: 219)
#
# Run: 498, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 15.38, max: 219)
#
# Run: 499, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 15.52, max: 219)
#
# Run: 500, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 15.87, max: 219)
#
# Run: 501, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.93, max: 219)
#
# Run: 502, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 16.13, max: 219)
#
# Run: 503, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.25, max: 219)
# Run: 504, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.27, max: 219)
#
# Run: 505, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.38, max: 219)
#
# Run: 506, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.45, max: 219)
#
# Run: 507, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.61, max: 219)
#
# Run: 508, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.69, max: 219)
#
# Run: 509, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.76, max: 219)
#
# Run: 510, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 17, max: 219)
#
# Run: 511, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.07, max: 219)
#
# Run: 512, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 17.36, max: 219)
#
# Run: 513, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.35, max: 219)
#
# Run: 514, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.42, max: 219)
#
# Run: 515, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.42, max: 219)
#
# Run: 516, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.63, max: 219)
#
# Run: 517, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.67, max: 219)
#
# Run: 518, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.89, max: 219)
#
# Run: 519, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 18, max: 219)
#
# Run: 520, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.01, max: 219)
#
# Run: 521, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.05, max: 219)
#
# Run: 522, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 18.11, max: 219)
#
# Run: 523, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 18.28, max: 219)
#
# Run: 524, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 18.4, max: 219)
#
# Run: 525, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 18.54, max: 219)
#
# Run: 526, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.53, max: 219)
#
# Run: 527, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.57, max: 219)
#
# Run: 528, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.65, max: 219)
#
# Run: 529, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 19.18, max: 219)
#
# Run: 530, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 19.73, max: 219)
#
# Run: 531, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.75, max: 219)
#
# Run: 532, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.75, max: 219)
#
# Run: 533, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.83, max: 219)
#
# Run: 534, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.91, max: 219)
#
# Run: 535, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 20.07, max: 219)
#
# Run: 536, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 20.17, max: 219)
#
# Run: 537, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.17, max: 219)
#
# Run: 538, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.19, max: 219)
#
# Run: 539, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 20.34, max: 219)
#
# Run: 540, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.39, max: 219)
#
# Run: 541, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.42, max: 219)
#
# Run: 542, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 20.7, max: 219)
#
# Run: 543, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 20.85, max: 219)
#
# Run: 544, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.9, max: 219)
#
# Run: 545, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.95, max: 219)
#
# Run: 546, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 21.09, max: 219)
#
# Run: 547, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 21.24, max: 219)
#
# Run: 548, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 21.39, max: 219)
#
# Run: 549, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 21.46, max: 219)
#
# Run: 550, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 21.68, max: 219)
#
# Run: 551, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 22.51, max: 219)
#
# Run: 552, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.52, max: 219)
#
# Run: 553, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 22.75, max: 219)
#
# Run: 554, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 22.92, max: 219)
#
# Run: 555, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 23.5, max: 219)
#
# Run: 556, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 23.58, max: 219)
#
# Run: 557, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 23.61, max: 219)
#
# Run: 558, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 23.63, max: 219)
#
# Run: 559, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 23.77, max: 219)
#
# Run: 560, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 23.83, max: 219)
#
# Run: 561, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 23.88, max: 219)
#
# Run: 562, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 23.88, max: 219)
#
# Run: 563, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 23.86, max: 219)
#
# Run: 564, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 24.14, max: 219)
#
# Run: 565, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 24.26, max: 219)
#
# Run: 566, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 24.74, max: 219)
#
# Run: 567, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 24.94, max: 219)
#
# Run: 568, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 25.13, max: 219)
#
# Run: 569, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 25.02, max: 219)
#
# Run: 570, exploration: 0.01, score: 86
# Scores: (min: 9, avg: 25.67, max: 219)
#
# Run: 571, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 25.62, max: 219)
#
# Run: 572, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 25.68, max: 219)
#
# Run: 573, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 25.73, max: 219)
#
# Run: 574, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 25.74, max: 219)
#
# Run: 575, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 26.64, max: 219)
#
# Run: 576, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 26.35, max: 219)
#
# Run: 577, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 26.33, max: 219)
#
# Run: 578, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 26.61, max: 219)
#
# Run: 579, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 26.8, max: 219)
#
# Run: 580, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 27.91, max: 219)
#
# Run: 581, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 28.88, max: 219)
#
# Run: 582, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 28.86, max: 219)
#
# Run: 583, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 28.75, max: 219)
#
# Run: 584, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 29.9, max: 219)
#
# Run: 585, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 29.85, max: 219)
#
# Run: 586, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 31.01, max: 219)
#
# Run: 587, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 31.76, max: 219)
#
# Run: 588, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 31.81, max: 219)
#
# Run: 589, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 32.51, max: 219)
#
# Run: 590, exploration: 0.01, score: 65
# ...
#
# Run: 1678, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.52, max: 64)
#
# Run: 1679, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.53, max: 64)
#
# Run: 1680, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 19.68, max: 64)
#
# Run: 1681, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.67, max: 64)
#
# Run: 1682, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.65, max: 64)
#
# Run: 1683, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.52, max: 64)
#
# Run: 1684, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 19.64, max: 64)
#
# Run: 1685, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 19.67, max: 64)
#
# Run: 1686, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 19.25, max: 64)
#
# Run: 1687, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 19.4, max: 64)
#
# Run: 1688, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 19.46, max: 64)
#
# Run: 1689, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.16, max: 64)
#
# Run: 1690, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 19.59, max: 64)
#
# Run: 1691, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 19.57, max: 64)
#
# Run: 1692, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 19.55, max: 64)
#
# Run: 1693, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.48, max: 64)
#
# Run: 1694, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.04, max: 64)
#
# Run: 1695, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 19.31, max: 64)
#
# Run: 1696, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.35, max: 64)
#
# Run: 1697, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.31, max: 64)
#
# Run: 1698, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 19.41, max: 64)
#
# Run: 1699, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 19.4, max: 64)
#
# Run: 1700, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.42, max: 64)
#
# Run: 1701, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.18, max: 64)
#
# Run: 1702, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.11, max: 64)
#
# Run: 1703, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.11, max: 64)
#
# Run: 1704, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.13, max: 64)
#
# Run: 1705, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 19.32, max: 64)
#
# Run: 1706, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.29, max: 64)
#
# Run: 1707, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.02, max: 64)
#
# Run: 1708, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 19.08, max: 64)
#
# Run: 1709, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 19.39, max: 64)
#
# Run: 1710, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 19.47, max: 64)
#
# Run: 1711, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.49, max: 64)
#
# Run: 1712, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.49, max: 64)
#
# Run: 1713, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.55, max: 64)
#
# Run: 1714, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.38, max: 64)
#
# Run: 1715, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.39, max: 64)
#
# Run: 1716, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.35, max: 64)
#
# Run: 1717, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 19.55, max: 64)
#
# Run: 1718, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 19.41, max: 64)
#
# Run: 1719, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 19.45, max: 64)
#
# Run: 1720, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.4, max: 64)
#
# Run: 1721, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.39, max: 64)
#
# Run: 1722, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.4, max: 64)
#
# Run: 1723, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 19.47, max: 64)
#
# Run: 1724, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 19.67, max: 64)
#
# Run: 1725, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.73, max: 64)
#
# Run: 1726, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 19.92, max: 64)
#
# Run: 1727, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 19.85, max: 64)
#
# Run: 1728, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.71, max: 64)
#
# Run: 1729, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 19.8, max: 64)
#
# Run: 1730, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 19.88, max: 64)
#
# Run: 1731, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.84, max: 64)
#
# Run: 1732, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 20.19, max: 64)
#
# Run: 1733, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 20.24, max: 64)
#
# Run: 1734, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 20.3, max: 64)
#
# Run: 1735, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.31, max: 64)
#
# Run: 1736, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.35, max: 64)
#
# Run: 1737, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.39, max: 64)
#
# Run: 1738, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.42, max: 64)
#
# Run: 1739, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.18, max: 64)
#
# Run: 1740, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 20.14, max: 64)
#
# Run: 1741, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 20.06, max: 64)
#
# Run: 1742, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 20.19, max: 64)
#
# Run: 1743, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 20.54, max: 64)
#
# Run: 1744, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.58, max: 64)
#
# Run: 1745, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 20.86, max: 64)
#
# Run: 1746, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.87, max: 64)
#
# Run: 1747, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 20.53, max: 64)
#
# Run: 1748, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 20.5, max: 64)
#
# Run: 1749, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.25, max: 64)
#
# Run: 1750, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 20.16, max: 64)
#
# Run: 1751, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.18, max: 64)
#
# Run: 1752, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 20.43, max: 64)
#
# Run: 1753, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 20.5, max: 64)
#
# Run: 1754, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.48, max: 64)
#
# Run: 1755, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 20.2, max: 55)
#
# Run: 1756, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.19, max: 55)
#
# Run: 1757, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 20.21, max: 55)
# Run: 1758, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 20.25, max: 55)
#
# Run: 1759, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.31, max: 55)
#
# Run: 1760, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 20.89, max: 69)
#
# Run: 1761, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.99, max: 69)
#
# Run: 1762, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.85, max: 69)
#
# Run: 1763, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.73, max: 69)
#
# Run: 1764, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.56, max: 69)
#
# Run: 1765, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 20.57, max: 69)
#
# Run: 1766, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.54, max: 69)
#
# Run: 1767, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 20.63, max: 69)
#
# Run: 1768, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 20.88, max: 69)
#
# Run: 1769, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.91, max: 69)
#
# Run: 1770, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.91, max: 69)
#
# Run: 1771, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.88, max: 69)
#
# Run: 1772, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 20.92, max: 69)
#
# Run: 1773, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 21, max: 69)
#
# Run: 1774, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.98, max: 69)
#
# Run: 1775, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.91, max: 69)
#
# Run: 1776, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 20.93, max: 69)
#
# Run: 1777, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.69, max: 69)
#
# Run: 1778, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 20.74, max: 69)
#
# Run: 1779, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 20.72, max: 69)
#
# Run: 1780, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 20.56, max: 69)
#
# Run: 1781, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.57, max: 69)
#
# Run: 1782, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 20.6, max: 69)
#
# Run: 1783, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 21.06, max: 69)
#
# Run: 1784, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 21.3, max: 69)
#
# Run: 1785, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 21.2, max: 69)
#
# Run: 1786, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 21.2, max: 69)
#
# Run: 1787, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 21.21, max: 69)
#
# Run: 1788, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 21.19, max: 69)
#
# Run: 1789, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.15, max: 69)
#
# Run: 1790, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.78, max: 69)
#
# Run: 1791, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.79, max: 69)
#
# Run: 1792, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.76, max: 69)
#
# Run: 1793, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.74, max: 69)
#
# Run: 1794, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 20.94, max: 69)
#
# Run: 1795, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.64, max: 69)
#
# Run: 1796, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 20.59, max: 69)
#
# Run: 1797, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.61, max: 69)
#
# Run: 1798, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.3, max: 69)
#
# Run: 1799, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 20.52, max: 69)
#
# Run: 1800, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 20.53, max: 69)
#
# Run: 1801, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 20.77, max: 69)
#
# Run: 1802, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.72, max: 69)
#
# Run: 1803, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.67, max: 69)
#
# Run: 1804, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.6, max: 69)
#
# Run: 1805, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.35, max: 69)
#
# Run: 1806, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 20.56, max: 69)
#
# Run: 1807, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 20.67, max: 69)
#
# Run: 1808, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 20.9, max: 69)
#
# Run: 1809, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 20.58, max: 69)
#
# Run: 1810, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.5, max: 69)
#
# Run: 1811, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 20.54, max: 69)
#
# Run: 1812, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.56, max: 69)
#
# Run: 1813, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 20.85, max: 69)
#
# Run: 1814, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 21.07, max: 69)
#
# Run: 1815, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 21.14, max: 69)
#
# Run: 1816, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 21.2, max: 69)
#
# Run: 1817, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.93, max: 69)
#
# Run: 1818, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 20.76, max: 69)
#
# Run: 1819, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 20.72, max: 69)
#
# Run: 1820, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.81, max: 69)
#
# Run: 1821, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.75, max: 69)
#
# Run: 1822, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 20.77, max: 69)
#
# Run: 1823, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.7, max: 69)
#
# Run: 1824, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.55, max: 69)
#
# Run: 1825, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 20.56, max: 69)
#
# Run: 1826, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 20.56, max: 69)
#
# Run: 1827, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 20.79, max: 69)
#
# Run: 1828, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 20.85, max: 69)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-5-9c34c072604d> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#
# <ipython-input-5-9c34c072604d> in experience_replay(self)
#      53             q_update = reward
#      54             if not terminal:
# ---> 55                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.5 #increase exploration factor  
EXPLORATION_MIN = 0.1  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.3501311418098665, score: 41
# Scores: (min: 41, avg: 41, max: 41)
#
# Run: 2, exploration: 1.1159712930101071, score: 39
# Scores: (min: 39, avg: 40, max: 41)
#
# Run: 3, exploration: 1.0299646397808, score: 17
# Scores: (min: 17, avg: 32.333333333333336, max: 41)
#
# Run: 4, exploration: 0.9747117539024632, score: 12
# Scores: (min: 12, avg: 27.25, max: 41)
#
# Run: 5, exploration: 0.9132217635538613, score: 14
# Scores: (min: 12, avg: 24.6, max: 41)
#
# Run: 6, exploration: 0.7288109456044766, score: 46
# Scores: (min: 12, avg: 28.166666666666668, max: 46)
#
# Run: 7, exploration: 0.605436882358516, score: 38
# Scores: (min: 12, avg: 29.571428571428573, max: 46)
#
# Run: 8, exploration: 0.5729579664079543, score: 12
# Scores: (min: 12, avg: 27.375, max: 46)
#
# Run: 9, exploration: 0.5504367325892504, score: 9
# Scores: (min: 9, avg: 25.333333333333332, max: 46)
#
# Run: 10, exploration: 0.5261567362272512, score: 10
# Scores: (min: 9, avg: 23.8, max: 46)
#
# Run: 11, exploration: 0.5004330020385458, score: 11
# Scores: (min: 9, avg: 22.636363636363637, max: 46)
#
# Run: 12, exploration: 0.47358706336896783, score: 12
# Scores: (min: 9, avg: 21.75, max: 46)
#
# Run: 13, exploration: 0.4392846640148536, score: 16
# Scores: (min: 9, avg: 21.307692307692307, max: 46)
#
# Run: 14, exploration: 0.4034023412603542, score: 18
# Scores: (min: 9, avg: 21.071428571428573, max: 46)
#
# Run: 15, exploration: 0.38176165315920163, score: 12
# Scores: (min: 9, avg: 20.466666666666665, max: 46)
#
# Run: 16, exploration: 0.3667557644939037, score: 9
# Scores: (min: 9, avg: 19.75, max: 46)
#
# Run: 17, exploration: 0.3470809974017863, score: 12
# Scores: (min: 9, avg: 19.294117647058822, max: 46)
#
# Run: 18, exploration: 0.3284616914573981, score: 12
# Scores: (min: 9, avg: 18.88888888888889, max: 46)
#
# Run: 19, exploration: 0.3092870198739589, score: 13
# Scores: (min: 9, avg: 18.57894736842105, max: 46)
#
# Run: 20, exploration: 0.2956442390187847, score: 10
# Scores: (min: 9, avg: 18.15, max: 46)
#
# Run: 21, exploration: 0.2811902307446102, score: 11
# Scores: (min: 9, avg: 17.80952380952381, max: 46)
#
# Run: 22, exploration: 0.27013749859771885, score: 9
# Scores: (min: 9, avg: 17.40909090909091, max: 46)
#
# Run: 23, exploration: 0.25693051153497365, score: 11
# Scores: (min: 9, avg: 17.130434782608695, max: 46)
#
# Run: 24, exploration: 0.24559719833835814, score: 10
# Scores: (min: 9, avg: 16.833333333333332, max: 46)
#
# Run: 25, exploration: 0.2359435199652775, score: 9
# Scores: (min: 9, avg: 16.52, max: 46)
#
# Run: 26, exploration: 0.22216979954296265, score: 13
# Scores: (min: 9, avg: 16.384615384615383, max: 46)
#
# Run: 27, exploration: 0.21025140729371727, score: 12
# Scores: (min: 9, avg: 16.22222222222222, max: 46)
#
# Run: 28, exploration: 0.19997224342173958, score: 11
# Scores: (min: 9, avg: 16.035714285714285, max: 46)
#
# Run: 29, exploration: 0.1921119431634391, score: 9
# Scores: (min: 9, avg: 15.793103448275861, max: 46)
#
# Run: 30, exploration: 0.1845606073848757, score: 9
# Scores: (min: 9, avg: 15.566666666666666, max: 46)
#
# Run: 31, exploration: 0.1746597760518279, score: 12
# Scores: (min: 9, avg: 15.451612903225806, max: 46)
#
# Run: 32, exploration: 0.1669554596862076, score: 10
# Scores: (min: 9, avg: 15.28125, max: 46)
#
# Run: 33, exploration: 0.15959098396394153, score: 10
# Scores: (min: 9, avg: 15.121212121212121, max: 46)
#
# Run: 34, exploration: 0.142927609076525, score: 23
# Scores: (min: 9, avg: 15.352941176470589, max: 46)
#
# Run: 35, exploration: 0.13526019743135484, score: 12
# Scores: (min: 9, avg: 15.257142857142858, max: 46)
#
# Run: 36, exploration: 0.1292938130912181, score: 10
# Scores: (min: 9, avg: 15.11111111111111, max: 46)
#
# Run: 37, exploration: 0.12359060848000561, score: 10
# Scores: (min: 9, avg: 14.972972972972974, max: 46)
#
# Run: 38, exploration: 0.11873263781799678, score: 9
# Scores: (min: 9, avg: 14.81578947368421, max: 46)
#
# Run: 39, exploration: 0.11124235289605744, score: 14
# Scores: (min: 9, avg: 14.794871794871796, max: 46)
#
# Run: 40, exploration: 0.10633540580531518, score: 10
# Scores: (min: 9, avg: 14.675, max: 46)
#
# Run: 41, exploration: 0.10215568464293742, score: 9
# Scores: (min: 9, avg: 14.536585365853659, max: 46)
#
# Run: 42, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 14.380952380952381, max: 46)
#
# Run: 43, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 14.232558139534884, max: 46)
#
# Run: 44, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 14.113636363636363, max: 46)
#
# Run: 45, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 14.022222222222222, max: 46)
#
# Run: 46, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 13.891304347826088, max: 46)
#
# Run: 47, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 13.76595744680851, max: 46)
#
# Run: 48, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 13.666666666666666, max: 46)
#
# Run: 49, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 13.63265306122449, max: 46)
#
# Run: 50, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 13.56, max: 46)
#
# Run: 51, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 13.490196078431373, max: 46)
#
# Run: 52, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 13.423076923076923, max: 46)
#
# Run: 53, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 13.358490566037736, max: 46)
#
# Run: 54, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 13.277777777777779, max: 46)
#
# Run: 55, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 13.218181818181819, max: 46)
#
# Run: 56, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 13.160714285714286, max: 46)
#
# Run: 57, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 13.105263157894736, max: 46)
#
# Run: 58, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 13.051724137931034, max: 46)
#
# Run: 59, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 12.966101694915254, max: 46)
#
# Run: 60, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 12.883333333333333, max: 46)
#
# Run: 61, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 12.852459016393443, max: 46)
#
# Run: 62, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.790322580645162, max: 46)
#
# Run: 63, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.746031746031745, max: 46)
#
# Run: 64, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 12.671875, max: 46)
#
# Run: 65, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.63076923076923, max: 46)
#
# Run: 66, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.590909090909092, max: 46)
#
# Run: 67, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.537313432835822, max: 46)
#
# Run: 68, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.485294117647058, max: 46)
#
# Run: 69, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.434782608695652, max: 46)
#
# Run: 70, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 12.414285714285715, max: 46)
#
# Run: 71, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.380281690140846, max: 46)
#
# Run: 72, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.333333333333334, max: 46)
#
# Run: 73, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.301369863013699, max: 46)
#
# Run: 74, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 12.31081081081081, max: 46)
#
# Run: 75, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.28, max: 46)
#
# Run: 76, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 12.302631578947368, max: 46)
#
# Run: 77, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.25974025974026, max: 46)
#
# Run: 78, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 12.256410256410257, max: 46)
#
# Run: 79, exploration: 0.1, score: 26
# Scores: (min: 8, avg: 12.430379746835444, max: 46)
#
# Run: 80, exploration: 0.1, score: 28
# Scores: (min: 8, avg: 12.625, max: 46)
#
# Run: 81, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 12.641975308641975, max: 46)
#
# Run: 82, exploration: 0.1, score: 24
# Scores: (min: 8, avg: 12.78048780487805, max: 46)
#
# Run: 83, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 12.819277108433734, max: 46)
#
# Run: 84, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 12.821428571428571, max: 46)
#
# Run: 85, exploration: 0.1, score: 29
# Scores: (min: 8, avg: 13.011764705882353, max: 46)
#
# Run: 86, exploration: 0.1, score: 24
# Scores: (min: 8, avg: 13.13953488372093, max: 46)
#
# Run: 87, exploration: 0.1, score: 23
# Scores: (min: 8, avg: 13.25287356321839, max: 46)
#
# Run: 88, exploration: 0.1, score: 23
# Scores: (min: 8, avg: 13.363636363636363, max: 46)
# Run: 89, exploration: 0.1, score: 17
# Scores: (min: 8, avg: 13.404494382022472, max: 46)
#
# Run: 90, exploration: 0.1, score: 21
# Scores: (min: 8, avg: 13.488888888888889, max: 46)
#
# Run: 91, exploration: 0.1, score: 28
# Scores: (min: 8, avg: 13.648351648351648, max: 46)
#
# Run: 92, exploration: 0.1, score: 32
# Scores: (min: 8, avg: 13.847826086956522, max: 46)
#
# Run: 93, exploration: 0.1, score: 25
# Scores: (min: 8, avg: 13.96774193548387, max: 46)
#
# Run: 94, exploration: 0.1, score: 33
# Scores: (min: 8, avg: 14.170212765957446, max: 46)
#
# Run: 95, exploration: 0.1, score: 23
# Scores: (min: 8, avg: 14.263157894736842, max: 46)
#
# Run: 96, exploration: 0.1, score: 18
# Scores: (min: 8, avg: 14.302083333333334, max: 46)
#
# Run: 97, exploration: 0.1, score: 22
# Scores: (min: 8, avg: 14.381443298969073, max: 46)
#
# Run: 98, exploration: 0.1, score: 40
# Scores: (min: 8, avg: 14.642857142857142, max: 46)
#
# Run: 99, exploration: 0.1, score: 45
# Scores: (min: 8, avg: 14.94949494949495, max: 46)
#
# Run: 100, exploration: 0.1, score: 29
# Scores: (min: 8, avg: 15.09, max: 46)
#
# Run: 101, exploration: 0.1, score: 61
# Scores: (min: 8, avg: 15.29, max: 61)
#
# Run: 102, exploration: 0.1, score: 46
# Scores: (min: 8, avg: 15.36, max: 61)
#
# Run: 103, exploration: 0.1, score: 38
# Scores: (min: 8, avg: 15.57, max: 61)
#
# Run: 104, exploration: 0.1, score: 30
# Scores: (min: 8, avg: 15.75, max: 61)
#
# Run: 105, exploration: 0.1, score: 108
# Scores: (min: 8, avg: 16.69, max: 108)
#
# Run: 106, exploration: 0.1, score: 32
# Scores: (min: 8, avg: 16.55, max: 108)
#
# Run: 107, exploration: 0.1, score: 18
# Scores: (min: 8, avg: 16.35, max: 108)
#
# Run: 108, exploration: 0.1, score: 51
# Scores: (min: 8, avg: 16.74, max: 108)
#
# Run: 109, exploration: 0.1, score: 38
# Scores: (min: 8, avg: 17.03, max: 108)
#
# Run: 110, exploration: 0.1, score: 65
# Scores: (min: 8, avg: 17.58, max: 108)
#
# Run: 111, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 17.63, max: 108)
#
# Run: 112, exploration: 0.1, score: 15
# Scores: (min: 8, avg: 17.66, max: 108)
#
# Run: 113, exploration: 0.1, score: 45
# Scores: (min: 8, avg: 17.95, max: 108)
#
# Run: 114, exploration: 0.1, score: 50
# Scores: (min: 8, avg: 18.27, max: 108)
#
# Run: 115, exploration: 0.1, score: 26
# Scores: (min: 8, avg: 18.41, max: 108)
#
# Run: 116, exploration: 0.1, score: 28
# Scores: (min: 8, avg: 18.6, max: 108)
#
# Run: 117, exploration: 0.1, score: 30
# Scores: (min: 8, avg: 18.78, max: 108)
#
# Run: 118, exploration: 0.1, score: 56
# Scores: (min: 8, avg: 19.22, max: 108)
#
# Run: 119, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 19.25, max: 108)
#
# Run: 120, exploration: 0.1, score: 83
# Scores: (min: 8, avg: 19.98, max: 108)
#
# Run: 121, exploration: 0.1, score: 48
# Scores: (min: 8, avg: 20.35, max: 108)
#
# Run: 122, exploration: 0.1, score: 20
# Scores: (min: 8, avg: 20.46, max: 108)
#
# Run: 123, exploration: 0.1, score: 36
# Scores: (min: 8, avg: 20.71, max: 108)
#
# Run: 124, exploration: 0.1, score: 46
# Scores: (min: 8, avg: 21.07, max: 108)
#
# Run: 125, exploration: 0.1, score: 41
# Scores: (min: 8, avg: 21.39, max: 108)
#
# Run: 126, exploration: 0.1, score: 40
# Scores: (min: 8, avg: 21.66, max: 108)
#
# Run: 127, exploration: 0.1, score: 81
# Scores: (min: 8, avg: 22.35, max: 108)
#
# Run: 128, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 22.37, max: 108)
#
# Run: 129, exploration: 0.1, score: 69
# Scores: (min: 8, avg: 22.97, max: 108)
#
# Run: 130, exploration: 0.1, score: 40
# Scores: (min: 8, avg: 23.28, max: 108)
#
# Run: 131, exploration: 0.1, score: 89
# Scores: (min: 8, avg: 24.05, max: 108)
#
# Run: 132, exploration: 0.1, score: 64
# Scores: (min: 8, avg: 24.59, max: 108)
#
# Run: 133, exploration: 0.1, score: 23
# Scores: (min: 8, avg: 24.72, max: 108)
#
# Run: 134, exploration: 0.1, score: 82
# Scores: (min: 8, avg: 25.31, max: 108)
#
# Run: 135, exploration: 0.1, score: 70
# Scores: (min: 8, avg: 25.89, max: 108)
#
# Run: 136, exploration: 0.1, score: 109
# Scores: (min: 8, avg: 26.88, max: 109)
#
# Run: 137, exploration: 0.1, score: 232
# Scores: (min: 8, avg: 29.1, max: 232)
#
# Run: 138, exploration: 0.1, score: 25
# Scores: (min: 8, avg: 29.26, max: 232)
#
# Run: 139, exploration: 0.1, score: 15
# Scores: (min: 8, avg: 29.27, max: 232)
#
# Run: 140, exploration: 0.1, score: 92
# Scores: (min: 8, avg: 30.09, max: 232)
#
# Run: 141, exploration: 0.1, score: 46
# Scores: (min: 8, avg: 30.46, max: 232)
#
# Run: 142, exploration: 0.1, score: 63
# Scores: (min: 8, avg: 31.01, max: 232)
#
# Run: 143, exploration: 0.1, score: 49
# Scores: (min: 8, avg: 31.42, max: 232)
#
# Run: 144, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 31.47, max: 232)
#
# Run: 145, exploration: 0.1, score: 17
# Scores: (min: 8, avg: 31.54, max: 232)
#
# Run: 146, exploration: 0.1, score: 131
# Scores: (min: 8, avg: 32.77, max: 232)
#
# Run: 147, exploration: 0.1, score: 84
# Scores: (min: 8, avg: 33.53, max: 232)
#
# Run: 148, exploration: 0.1, score: 45
# Scores: (min: 8, avg: 33.89, max: 232)
#
# Run: 149, exploration: 0.1, score: 114
# Scores: (min: 8, avg: 34.91, max: 232)
#
# Run: 150, exploration: 0.1, score: 48
# Scores: (min: 8, avg: 35.29, max: 232)
#
# Run: 151, exploration: 0.1, score: 21
# Scores: (min: 8, avg: 35.4, max: 232)
#
# Run: 152, exploration: 0.1, score: 40
# Scores: (min: 8, avg: 35.7, max: 232)
#
# Run: 153, exploration: 0.1, score: 54
# Scores: (min: 8, avg: 36.14, max: 232)
#
# Run: 154, exploration: 0.1, score: 132
# Scores: (min: 8, avg: 37.37, max: 232)
#
# Run: 155, exploration: 0.1, score: 26
# Scores: (min: 8, avg: 37.53, max: 232)
#
# Run: 156, exploration: 0.1, score: 183
# Scores: (min: 8, avg: 39.26, max: 232)
#
# Run: 157, exploration: 0.1, score: 126
# Scores: (min: 8, avg: 40.42, max: 232)
#
# Run: 158, exploration: 0.1, score: 137
# Scores: (min: 8, avg: 41.69, max: 232)
#
# Run: 159, exploration: 0.1, score: 213
# Scores: (min: 8, avg: 43.74, max: 232)
#
# Run: 160, exploration: 0.1, score: 229
# Scores: (min: 8, avg: 45.95, max: 232)
#
# Run: 161, exploration: 0.1, score: 276
# Scores: (min: 8, avg: 48.6, max: 276)
#
# Run: 162, exploration: 0.1, score: 234
# Scores: (min: 8, avg: 50.85, max: 276)
#
# Run: 163, exploration: 0.1, score: 237
# Scores: (min: 8, avg: 53.12, max: 276)
#
# Run: 164, exploration: 0.1, score: 258
# Scores: (min: 9, avg: 55.62, max: 276)
#
# Run: 165, exploration: 0.1, score: 199
# Scores: (min: 9, avg: 57.51, max: 276)
#
# Run: 166, exploration: 0.1, score: 207
# Scores: (min: 9, avg: 59.48, max: 276)
#
# Run: 167, exploration: 0.1, score: 226
# Scores: (min: 9, avg: 61.65, max: 276)
#
# Run: 168, exploration: 0.1, score: 202
# Scores: (min: 9, avg: 63.58, max: 276)
#
# Run: 169, exploration: 0.1, score: 286
# Scores: (min: 9, avg: 66.35, max: 286)
#
# Run: 170, exploration: 0.1, score: 243
# Scores: (min: 9, avg: 68.67, max: 286)
#
# Run: 171, exploration: 0.1, score: 371
# Scores: (min: 9, avg: 72.28, max: 371)
#
# Run: 172, exploration: 0.1, score: 189
# Scores: (min: 9, avg: 74.08, max: 371)
#
# Run: 173, exploration: 0.1, score: 220
# Scores: (min: 9, avg: 76.18, max: 371)
#
# Run: 174, exploration: 0.1, score: 190
# Scores: (min: 9, avg: 77.95, max: 371)
#
# Run: 175, exploration: 0.1, score: 245
# Scores: (min: 9, avg: 80.3, max: 371)
#
# Run: 176, exploration: 0.1, score: 207
# Scores: (min: 9, avg: 82.23, max: 371)
#
# Run: 177, exploration: 0.1, score: 212
# Scores: (min: 12, avg: 84.26, max: 371)
#
# Run: 178, exploration: 0.1, score: 199
# Scores: (min: 13, avg: 86.13, max: 371)
#
# Run: 179, exploration: 0.1, score: 252
# Scores: (min: 13, avg: 88.39, max: 371)
#
# Run: 180, exploration: 0.1, score: 184
# Scores: (min: 13, avg: 89.95, max: 371)
#
# Run: 181, exploration: 0.1, score: 159
# Scores: (min: 13, avg: 91.4, max: 371)
#
# Run: 182, exploration: 0.1, score: 238
# Scores: (min: 13, avg: 93.54, max: 371)
#
# Run: 183, exploration: 0.1, score: 209
# Scores: (min: 13, avg: 95.47, max: 371)
#
# Run: 184, exploration: 0.1, score: 193
# Scores: (min: 13, avg: 97.27, max: 371)
#
# Run: 185, exploration: 0.1, score: 229
# Scores: (min: 13, avg: 99.27, max: 371)
#
# Run: 186, exploration: 0.1, score: 231
# Scores: (min: 13, avg: 101.34, max: 371)
#
# Run: 187, exploration: 0.1, score: 183
# Scores: (min: 13, avg: 102.94, max: 371)
#
# Run: 188, exploration: 0.1, score: 434
# Scores: (min: 13, avg: 107.05, max: 434)
#
# Run: 189, exploration: 0.1, score: 195
# Scores: (min: 13, avg: 108.83, max: 434)
#
# Run: 190, exploration: 0.1, score: 178
# Scores: (min: 13, avg: 110.4, max: 434)
#
# Run: 191, exploration: 0.1, score: 138
# Scores: (min: 13, avg: 111.5, max: 434)
# Run: 192, exploration: 0.1, score: 162
# Scores: (min: 13, avg: 112.8, max: 434)
#
# Run: 193, exploration: 0.1, score: 232
# Scores: (min: 13, avg: 114.87, max: 434)
#
# Run: 194, exploration: 0.1, score: 187
# Scores: (min: 13, avg: 116.41, max: 434)
#
# Run: 195, exploration: 0.1, score: 158
# Scores: (min: 13, avg: 117.76, max: 434)
#
# Run: 196, exploration: 0.1, score: 234
# Scores: (min: 13, avg: 119.92, max: 434)
#
# Run: 197, exploration: 0.1, score: 152
# Scores: (min: 13, avg: 121.22, max: 434)
#
# Run: 198, exploration: 0.1, score: 172
# Scores: (min: 13, avg: 122.54, max: 434)
#
# Run: 199, exploration: 0.1, score: 405
# Scores: (min: 13, avg: 126.14, max: 434)
#
# Run: 200, exploration: 0.1, score: 190
# Scores: (min: 13, avg: 127.75, max: 434)
#
# Run: 201, exploration: 0.1, score: 260
# Scores: (min: 13, avg: 129.74, max: 434)
#
# Run: 202, exploration: 0.1, score: 163
# Scores: (min: 13, avg: 130.91, max: 434)
#
# Run: 203, exploration: 0.1, score: 234
# Scores: (min: 13, avg: 132.87, max: 434)
#
# Run: 204, exploration: 0.1, score: 149
# Scores: (min: 13, avg: 134.06, max: 434)
#
# Run: 205, exploration: 0.1, score: 203
# Scores: (min: 13, avg: 135.01, max: 434)
#
# Run: 206, exploration: 0.1, score: 150
# Scores: (min: 13, avg: 136.19, max: 434)
#
# Run: 207, exploration: 0.1, score: 193
# Scores: (min: 13, avg: 137.94, max: 434)
#
# Run: 208, exploration: 0.1, score: 167
# Scores: (min: 13, avg: 139.1, max: 434)
#
# Run: 209, exploration: 0.1, score: 172
# Scores: (min: 13, avg: 140.44, max: 434)
#
# Run: 210, exploration: 0.1, score: 259
# Scores: (min: 13, avg: 142.38, max: 434)
#
# Run: 211, exploration: 0.1, score: 181
# Scores: (min: 13, avg: 144.03, max: 434)
#
# Run: 212, exploration: 0.1, score: 125
# Scores: (min: 13, avg: 145.13, max: 434)
#
# Run: 213, exploration: 0.1, score: 163
# Scores: (min: 13, avg: 146.31, max: 434)
#
# Run: 214, exploration: 0.1, score: 175
# Scores: (min: 13, avg: 147.56, max: 434)
#
# Run: 215, exploration: 0.1, score: 152
# Scores: (min: 13, avg: 148.82, max: 434)
#
# Run: 216, exploration: 0.1, score: 174
# Scores: (min: 13, avg: 150.28, max: 434)
#
# Run: 217, exploration: 0.1, score: 264
# Scores: (min: 13, avg: 152.62, max: 434)
#
# Run: 218, exploration: 0.1, score: 91
# Scores: (min: 13, avg: 152.97, max: 434)
#
# Run: 219, exploration: 0.1, score: 253
# Scores: (min: 13, avg: 155.34, max: 434)
#
# Run: 220, exploration: 0.1, score: 436
# Scores: (min: 13, avg: 158.87, max: 436)
#
# Run: 221, exploration: 0.1, score: 188
# Scores: (min: 13, avg: 160.27, max: 436)
#
# Run: 222, exploration: 0.1, score: 178
# Scores: (min: 13, avg: 161.85, max: 436)
#
# Run: 223, exploration: 0.1, score: 230
# Scores: (min: 13, avg: 163.79, max: 436)
#
# Run: 224, exploration: 0.1, score: 142
# Scores: (min: 13, avg: 164.75, max: 436)
#
# Run: 225, exploration: 0.1, score: 238
# Scores: (min: 13, avg: 166.72, max: 436)
#
# Run: 226, exploration: 0.1, score: 294
# Scores: (min: 13, avg: 169.26, max: 436)
#
# Run: 227, exploration: 0.1, score: 164
# Scores: (min: 13, avg: 170.09, max: 436)
#
# Run: 228, exploration: 0.1, score: 318
# Scores: (min: 14, avg: 173.14, max: 436)
#
# Run: 229, exploration: 0.1, score: 12
# Scores: (min: 12, avg: 172.57, max: 436)
#
# Run: 230, exploration: 0.1, score: 170
# Scores: (min: 12, avg: 173.87, max: 436)
#
# Run: 231, exploration: 0.1, score: 169
# Scores: (min: 12, avg: 174.67, max: 436)
#
# Run: 232, exploration: 0.1, score: 83
# Scores: (min: 12, avg: 174.86, max: 436)
#
# Run: 233, exploration: 0.1, score: 256
# Scores: (min: 12, avg: 177.19, max: 436)
#
# Run: 234, exploration: 0.1, score: 297
# Scores: (min: 12, avg: 179.34, max: 436)
#
# Run: 235, exploration: 0.1, score: 150
# Scores: (min: 12, avg: 180.14, max: 436)
#
# Run: 236, exploration: 0.1, score: 168
# Scores: (min: 12, avg: 180.73, max: 436)
#
# Run: 237, exploration: 0.1, score: 65
# Scores: (min: 12, avg: 179.06, max: 436)
#
# Run: 238, exploration: 0.1, score: 11
# Scores: (min: 11, avg: 178.92, max: 436)
#
# Run: 239, exploration: 0.1, score: 10
# Scores: (min: 10, avg: 178.87, max: 436)
#
# Run: 240, exploration: 0.1, score: 11
# Scores: (min: 10, avg: 178.06, max: 436)
#
# Run: 241, exploration: 0.1, score: 11
# Scores: (min: 10, avg: 177.71, max: 436)
#
# Run: 242, exploration: 0.1, score: 37
# Scores: (min: 10, avg: 177.45, max: 436)
#
# Run: 243, exploration: 0.1, score: 125
# Scores: (min: 10, avg: 178.21, max: 436)
#
# Run: 244, exploration: 0.1, score: 123
# Scores: (min: 10, avg: 179.3, max: 436)
#
# Run: 245, exploration: 0.1, score: 117
# Scores: (min: 10, avg: 180.3, max: 436)
#
# Run: 246, exploration: 0.1, score: 64
# Scores: (min: 10, avg: 179.63, max: 436)
#
# Run: 247, exploration: 0.1, score: 135
# Scores: (min: 10, avg: 180.14, max: 436)
#
# Run: 248, exploration: 0.1, score: 164
# Scores: (min: 10, avg: 181.33, max: 436)
#
# Run: 249, exploration: 0.1, score: 198
# Scores: (min: 10, avg: 182.17, max: 436)
#
# Run: 250, exploration: 0.1, score: 169
# Scores: (min: 10, avg: 183.38, max: 436)
#
# Run: 251, exploration: 0.1, score: 163
# Scores: (min: 10, avg: 184.8, max: 436)
#
# Run: 252, exploration: 0.1, score: 169
# Scores: (min: 10, avg: 186.09, max: 436)
#
# Run: 253, exploration: 0.1, score: 186
# Scores: (min: 10, avg: 187.41, max: 436)
#
# Run: 254, exploration: 0.1, score: 40
# Scores: (min: 10, avg: 186.49, max: 436)
#
# Run: 255, exploration: 0.1, score: 110
# Scores: (min: 10, avg: 187.33, max: 436)
#
# Run: 256, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 185.58, max: 436)
#
# Run: 257, exploration: 0.1, score: 127
# Scores: (min: 8, avg: 185.59, max: 436)
#
# Run: 258, exploration: 0.1, score: 176
# Scores: (min: 8, avg: 185.98, max: 436)
#
# Run: 259, exploration: 0.1, score: 68
# Scores: (min: 8, avg: 184.53, max: 436)
#
# Run: 260, exploration: 0.1, score: 224
# Scores: (min: 8, avg: 184.48, max: 436)
#
# Run: 261, exploration: 0.1, score: 154
# Scores: (min: 8, avg: 183.26, max: 436)
#
# Run: 262, exploration: 0.1, score: 146
# Scores: (min: 8, avg: 182.38, max: 436)
#
# Run: 263, exploration: 0.1, score: 161
# Scores: (min: 8, avg: 181.62, max: 436)
#
# Run: 264, exploration: 0.1, score: 133
# Scores: (min: 8, avg: 180.37, max: 436)
#
# Run: 265, exploration: 0.1, score: 146
# Scores: (min: 8, avg: 179.84, max: 436)
#
# Run: 266, exploration: 0.1, score: 143
# Scores: (min: 8, avg: 179.2, max: 436)
#
# Run: 267, exploration: 0.1, score: 161
# Scores: (min: 8, avg: 178.55, max: 436)
#
# Run: 268, exploration: 0.1, score: 160
# Scores: (min: 8, avg: 178.13, max: 436)
#
# Run: 269, exploration: 0.1, score: 284
# Scores: (min: 8, avg: 178.11, max: 436)
#
# Run: 270, exploration: 0.1, score: 126
# Scores: (min: 8, avg: 176.94, max: 436)
#
# Run: 271, exploration: 0.1, score: 29
# Scores: (min: 8, avg: 173.52, max: 436)
#
# Run: 272, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 171.74, max: 436)
#
# Run: 273, exploration: 0.1, score: 198
# Scores: (min: 8, avg: 171.52, max: 436)
#
# Run: 274, exploration: 0.1, score: 22
# Scores: (min: 8, avg: 169.84, max: 436)
#
# Run: 275, exploration: 0.1, score: 187
# Scores: (min: 8, avg: 169.26, max: 436)
#
# Run: 276, exploration: 0.1, score: 142
# Scores: (min: 8, avg: 168.61, max: 436)
#
# Run: 277, exploration: 0.1, score: 114
# Scores: (min: 8, avg: 167.63, max: 436)
#
# Run: 278, exploration: 0.1, score: 153
# Scores: (min: 8, avg: 167.17, max: 436)
#
# Run: 279, exploration: 0.1, score: 160
# Scores: (min: 8, avg: 166.25, max: 436)
#
# Run: 280, exploration: 0.1, score: 87
# Scores: (min: 8, avg: 165.28, max: 436)
#
# Run: 281, exploration: 0.1, score: 146
# Scores: (min: 8, avg: 165.15, max: 436)
#
# Run: 282, exploration: 0.1, score: 237
# Scores: (min: 8, avg: 165.14, max: 436)
#
# Run: 283, exploration: 0.1, score: 120
# Scores: (min: 8, avg: 164.25, max: 436)
#
# Run: 284, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 162.44, max: 436)
#
# Run: 285, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 160.25, max: 436)
#
# Run: 286, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 158.04, max: 436)
#
# Run: 287, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 156.3, max: 436)
#
# Run: 288, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 152.06, max: 436)
#
# Run: 289, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 150.2, max: 436)
#
# Run: 290, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 148.52, max: 436)
#
# Run: 291, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 147.24, max: 436)
#
# Run: 292, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 145.72, max: 436)
#
# Run: 293, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 143.5, max: 436)
#
# Run: 294, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 141.74, max: 436)
# Run: 295, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 140.27, max: 436)
#
# Run: 296, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 138.03, max: 436)
#
# Run: 297, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 136.61, max: 436)
#
# Run: 298, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 134.99, max: 436)
#
# Run: 299, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 131.04, max: 436)
#
# Run: 300, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 129.22, max: 436)
#
# Run: 301, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 126.71, max: 436)
#
# Run: 302, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 125.21, max: 436)
#
# Run: 303, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 122.97, max: 436)
#
# Run: 304, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 121.6, max: 436)
#
# Run: 305, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 119.67, max: 436)
#
# Run: 306, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 118.26, max: 436)
#
# Run: 307, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 116.42, max: 436)
#
# Run: 308, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 114.85, max: 436)
#
# Run: 309, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 113.23, max: 436)
#
# Run: 310, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 110.74, max: 436)
#
# Run: 311, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 109.04, max: 436)
#
# Run: 312, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 107.89, max: 436)
#
# Run: 313, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 106.36, max: 436)
#
# Run: 314, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 104.71, max: 436)
#
# Run: 315, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 103.31, max: 436)
#
# Run: 316, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 101.67, max: 436)
#
# Run: 317, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 99.12, max: 436)
#
# Run: 318, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 98.31, max: 436)
#
# Run: 319, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 95.88, max: 436)
#
# Run: 320, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 91.62, max: 318)
#
# Run: 321, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 89.83, max: 318)
#
# Run: 322, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 88.15, max: 318)
#
# Run: 323, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 85.95, max: 318)
#
# Run: 324, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 84.63, max: 318)
#
# Run: 325, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 82.35, max: 318)
#
# Run: 326, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 79.51, max: 318)
#
# Run: 327, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 77.99, max: 318)
#
# Run: 328, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 74.9, max: 297)
#
# Run: 329, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 74.9, max: 297)
#
# Run: 330, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 73.29, max: 297)
#
# Run: 331, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 71.68, max: 297)
#
# Run: 332, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 70.94, max: 297)
#
# Run: 333, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 68.48, max: 297)
#
# Run: 334, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 65.59, max: 284)
#
# Run: 335, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 64.21, max: 284)
#
# Run: 336, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 62.63, max: 284)
#
# Run: 337, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 62.08, max: 284)
#
# Run: 338, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 62.06, max: 284)
#
# Run: 339, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 62.04, max: 284)
#
# Run: 340, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 62.04, max: 284)
#
# Run: 341, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 62.04, max: 284)
#
# Run: 342, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 61.77, max: 284)
#
# Run: 343, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 60.61, max: 284)
#
# Run: 344, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 59.48, max: 284)
#
# Run: 345, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 58.43, max: 284)
#
# Run: 346, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 57.89, max: 284)
#
# Run: 347, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 56.64, max: 284)
#
# Run: 348, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 55.1, max: 284)
#
# Run: 349, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 53.21, max: 284)
#
# Run: 350, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 51.62, max: 284)
#
# Run: 351, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 50.09, max: 284)
#
# Run: 352, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 48.52, max: 284)
#
# Run: 353, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 46.76, max: 284)
#
# Run: 354, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 46.45, max: 284)
#
# Run: 355, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 45.44, max: 284)
#
# Run: 356, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 45.46, max: 284)
#
# Run: 357, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 44.28, max: 284)
#
# Run: 358, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 42.62, max: 284)
#
# Run: 359, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 42.04, max: 284)
#
# Run: 360, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 39.91, max: 284)
#
# Run: 361, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 38.45, max: 284)
#
# Run: 362, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 37.09, max: 284)
#
# Run: 363, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 35.57, max: 284)
#
# Run: 364, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 34.35, max: 284)
#
# Run: 365, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 32.98, max: 284)
#
# Run: 366, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 31.63, max: 284)
#
# Run: 367, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 30.1, max: 284)
#
# Run: 368, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 28.59, max: 284)
#
# Run: 369, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 25.84, max: 237)
#
# Run: 370, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 24.67, max: 237)
#
# Run: 371, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 24.47, max: 237)
#
# Run: 372, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 24.46, max: 237)
#
# Run: 373, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 22.57, max: 237)
#
# Run: 374, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 22.43, max: 237)
#
# Run: 375, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 20.65, max: 237)
#
# Run: 376, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 19.34, max: 237)
#
# Run: 377, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 18.28, max: 237)
#
# Run: 378, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 16.85, max: 237)
#
# Run: 379, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 15.36, max: 237)
#
# Run: 380, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 14.59, max: 237)
#
# Run: 381, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 13.23, max: 237)
#
# Run: 382, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 10.97, max: 120)
#
# Run: 383, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.86, max: 13)
#
# Run: 384, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 385, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 386, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 387, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 9.87, max: 13)
#
# Run: 388, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.86, max: 13)
#
# Run: 389, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.87, max: 13)
#
# Run: 390, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.87, max: 13)
#
# Run: 391, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.88, max: 13)
#
# Run: 392, exploration: 0.1, score: 15
# Scores: (min: 8, avg: 9.93, max: 15)
#
# Run: 393, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 9.96, max: 15)
#
# Run: 394, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 10.01, max: 16)
#
# Run: 395, exploration: 0.1, score: 15
# Scores: (min: 8, avg: 10.05, max: 16)
#
# Run: 396, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 10.11, max: 16)
#
# Run: 397, exploration: 0.1, score: 18
# Scores: (min: 8, avg: 10.19, max: 18)
#
# Run: 398, exploration: 0.1, score: 20
# Scores: (min: 8, avg: 10.29, max: 20)
#
# Run: 399, exploration: 0.1, score: 31
# Scores: (min: 8, avg: 10.5, max: 31)
#
# Run: 400, exploration: 0.1, score: 98
# Scores: (min: 8, avg: 11.4, max: 98)
# Run: 401, exploration: 0.1, score: 73
# Scores: (min: 8, avg: 12.04, max: 98)
#
# Run: 402, exploration: 0.1, score: 55
# Scores: (min: 8, avg: 12.46, max: 98)
#
# Run: 403, exploration: 0.1, score: 34
# Scores: (min: 8, avg: 12.7, max: 98)
#
# Run: 404, exploration: 0.1, score: 64
# Scores: (min: 8, avg: 13.22, max: 98)
#
# Run: 405, exploration: 0.1, score: 54
# Scores: (min: 8, avg: 13.66, max: 98)
#
# Run: 406, exploration: 0.1, score: 61
# Scores: (min: 8, avg: 14.18, max: 98)
#
# Run: 407, exploration: 0.1, score: 56
# Scores: (min: 8, avg: 14.65, max: 98)
#
# Run: 408, exploration: 0.1, score: 56
# Scores: (min: 8, avg: 15.11, max: 98)
#
# Run: 409, exploration: 0.1, score: 58
# Scores: (min: 8, avg: 15.59, max: 98)
#
# Run: 410, exploration: 0.1, score: 67
# Scores: (min: 8, avg: 16.16, max: 98)
#
# Run: 411, exploration: 0.1, score: 105
# Scores: (min: 8, avg: 17.1, max: 105)
#
# Run: 412, exploration: 0.1, score: 80
# Scores: (min: 8, avg: 17.8, max: 105)
#
# Run: 413, exploration: 0.1, score: 144
# Scores: (min: 8, avg: 19.14, max: 144)
#
# Run: 414, exploration: 0.1, score: 220
# Scores: (min: 8, avg: 21.24, max: 220)
#
# Run: 415, exploration: 0.1, score: 188
# Scores: (min: 8, avg: 23, max: 220)
#
# Run: 416, exploration: 0.1, score: 405
# Scores: (min: 8, avg: 26.95, max: 405)
#
# Run: 417, exploration: 0.1, score: 122
# Scores: (min: 8, avg: 28.08, max: 405)
#
# Run: 418, exploration: 0.1, score: 177
# Scores: (min: 8, avg: 29.75, max: 405)
#
# Run: 419, exploration: 0.1, score: 128
# Scores: (min: 8, avg: 30.93, max: 405)
#
# Run: 420, exploration: 0.1, score: 30
# Scores: (min: 8, avg: 31.13, max: 405)
#
# Run: 421, exploration: 0.1, score: 125
# Scores: (min: 8, avg: 32.29, max: 405)
#
# Run: 422, exploration: 0.1, score: 264
# Scores: (min: 8, avg: 34.83, max: 405)
#
# Run: 423, exploration: 0.1, score: 143
# Scores: (min: 8, avg: 36.16, max: 405)
#
# Run: 424, exploration: 0.1, score: 183
# Scores: (min: 8, avg: 37.89, max: 405)
#
# Run: 425, exploration: 0.1, score: 58
# Scores: (min: 8, avg: 38.37, max: 405)
#
# Run: 426, exploration: 0.1, score: 112
# Scores: (min: 8, avg: 39.39, max: 405)
#
# Run: 427, exploration: 0.1, score: 129
# Scores: (min: 8, avg: 40.56, max: 405)
#
# Run: 428, exploration: 0.1, score: 157
# Scores: (min: 8, avg: 42.04, max: 405)
#
# Run: 429, exploration: 0.1, score: 101
# Scores: (min: 8, avg: 42.93, max: 405)
#
# Run: 430, exploration: 0.1, score: 108
# Scores: (min: 8, avg: 43.92, max: 405)
#
# Run: 431, exploration: 0.1, score: 132
# Scores: (min: 8, avg: 45.16, max: 405)
#
# Run: 432, exploration: 0.1, score: 207
# Scores: (min: 8, avg: 47.14, max: 405)
#
# Run: 433, exploration: 0.1, score: 208
# Scores: (min: 8, avg: 49.12, max: 405)
#
# Run: 434, exploration: 0.1, score: 328
# Scores: (min: 8, avg: 52.32, max: 405)
#
# Run: 435, exploration: 0.1, score: 296
# Scores: (min: 8, avg: 55.16, max: 405)
#
# Run: 436, exploration: 0.1, score: 86
# Scores: (min: 8, avg: 55.92, max: 405)
#
# Run: 437, exploration: 0.1, score: 175
# Scores: (min: 8, avg: 57.57, max: 405)
#
# Run: 438, exploration: 0.1, score: 225
# Scores: (min: 8, avg: 59.73, max: 405)
#
# Run: 439, exploration: 0.1, score: 176
# Scores: (min: 8, avg: 61.41, max: 405)
#
# Run: 440, exploration: 0.1, score: 56
# Scores: (min: 8, avg: 61.86, max: 405)
#
# Run: 441, exploration: 0.1, score: 33
# Scores: (min: 8, avg: 62.08, max: 405)
#
# Run: 442, exploration: 0.1, score: 122
# Scores: (min: 8, avg: 63.2, max: 405)
#
# Run: 443, exploration: 0.1, score: 256
# Scores: (min: 8, avg: 65.67, max: 405)
#
# Run: 444, exploration: 0.1, score: 120
# Scores: (min: 8, avg: 66.77, max: 405)
#
# Run: 445, exploration: 0.1, score: 187
# Scores: (min: 8, avg: 68.52, max: 405)
#
# Run: 446, exploration: 0.1, score: 124
# Scores: (min: 8, avg: 69.66, max: 405)
#
# Run: 447, exploration: 0.1, score: 183
# Scores: (min: 8, avg: 71.39, max: 405)
#
# Run: 448, exploration: 0.1, score: 129
# Scores: (min: 8, avg: 72.58, max: 405)
#
# Run: 449, exploration: 0.1, score: 211
# Scores: (min: 8, avg: 74.6, max: 405)
#
# Run: 450, exploration: 0.1, score: 229
# Scores: (min: 8, avg: 76.79, max: 405)
#
# Run: 451, exploration: 0.1, score: 236
# Scores: (min: 8, avg: 79.05, max: 405)
#
# Run: 452, exploration: 0.1, score: 178
# Scores: (min: 8, avg: 80.71, max: 405)
#
# Run: 453, exploration: 0.1, score: 229
# Scores: (min: 8, avg: 82.9, max: 405)
#
# Run: 454, exploration: 0.1, score: 74
# Scores: (min: 8, avg: 83.55, max: 405)
#
# Run: 455, exploration: 0.1, score: 148
# Scores: (min: 8, avg: 84.94, max: 405)
#
# Run: 456, exploration: 0.1, score: 71
# Scores: (min: 8, avg: 85.55, max: 405)
#
# Run: 457, exploration: 0.1, score: 159
# Scores: (min: 8, avg: 87.05, max: 405)
#
# Run: 458, exploration: 0.1, score: 224
# Scores: (min: 8, avg: 89.19, max: 405)
#
# Run: 459, exploration: 0.1, score: 224
# Scores: (min: 8, avg: 91.33, max: 405)
#
# Run: 460, exploration: 0.1, score: 374
# Scores: (min: 8, avg: 94.96, max: 405)
#
# Run: 461, exploration: 0.1, score: 176
# Scores: (min: 8, avg: 96.64, max: 405)
#
# Run: 462, exploration: 0.1, score: 307
# Scores: (min: 8, avg: 99.61, max: 405)
#
# Run: 463, exploration: 0.1, score: 178
# Scores: (min: 8, avg: 101.3, max: 405)
#
# Run: 464, exploration: 0.1, score: 349
# Scores: (min: 8, avg: 104.68, max: 405)
#
# Run: 465, exploration: 0.1, score: 221
# Scores: (min: 8, avg: 106.8, max: 405)
#
# Run: 466, exploration: 0.1, score: 142
# Scores: (min: 8, avg: 108.14, max: 405)
#
# Run: 467, exploration: 0.1, score: 133
# Scores: (min: 8, avg: 109.39, max: 405)
#
# Run: 468, exploration: 0.1, score: 81
# Scores: (min: 8, avg: 110.11, max: 405)
#
# Run: 469, exploration: 0.1, score: 124
# Scores: (min: 8, avg: 111.26, max: 405)
#
# Run: 470, exploration: 0.1, score: 198
# Scores: (min: 8, avg: 113.15, max: 405)
#
# Run: 471, exploration: 0.1, score: 211
# Scores: (min: 8, avg: 115.17, max: 405)
#
# Run: 472, exploration: 0.1, score: 146
# Scores: (min: 8, avg: 116.53, max: 405)
#
# Run: 473, exploration: 0.1, score: 62
# Scores: (min: 8, avg: 117.06, max: 405)
#
# Run: 474, exploration: 0.1, score: 181
# Scores: (min: 8, avg: 118.79, max: 405)
#
# Run: 475, exploration: 0.1, score: 155
# Scores: (min: 8, avg: 120.25, max: 405)
#
# Run: 476, exploration: 0.1, score: 154
# Scores: (min: 8, avg: 121.68, max: 405)
#
# Run: 477, exploration: 0.1, score: 152
# Scores: (min: 9, avg: 123.12, max: 405)
#
# Run: 478, exploration: 0.1, score: 120
# Scores: (min: 9, avg: 124.22, max: 405)
#
# Run: 479, exploration: 0.1, score: 138
# Scores: (min: 9, avg: 125.49, max: 405)
#
# Run: 480, exploration: 0.1, score: 92
# Scores: (min: 9, avg: 126.31, max: 405)
#
# Run: 481, exploration: 0.1, score: 188
# Scores: (min: 9, avg: 128.09, max: 405)
#
# Run: 482, exploration: 0.1, score: 359
# Scores: (min: 9, avg: 131.57, max: 405)
#
# Run: 483, exploration: 0.1, score: 220
# Scores: (min: 9, avg: 133.68, max: 405)
#
# Run: 484, exploration: 0.1, score: 340
# Scores: (min: 9, avg: 136.98, max: 405)
#
# Run: 485, exploration: 0.1, score: 253
# Scores: (min: 9, avg: 139.41, max: 405)
#
# Run: 486, exploration: 0.1, score: 213
# Scores: (min: 9, avg: 141.44, max: 405)
#
# Run: 487, exploration: 0.1, score: 23
# Scores: (min: 9, avg: 141.55, max: 405)
#
# Run: 488, exploration: 0.1, score: 218
# Scores: (min: 10, avg: 143.64, max: 405)
#
# Run: 489, exploration: 0.1, score: 117
# Scores: (min: 10, avg: 144.71, max: 405)
#
# Run: 490, exploration: 0.1, score: 236
# Scores: (min: 11, avg: 146.97, max: 405)
#
# Run: 491, exploration: 0.1, score: 126
# Scores: (min: 13, avg: 148.12, max: 405)
#
# Run: 492, exploration: 0.1, score: 175
# Scores: (min: 13, avg: 149.72, max: 405)
#
# Run: 493, exploration: 0.1, score: 296
# Scores: (min: 15, avg: 152.55, max: 405)
#
# Run: 494, exploration: 0.1, score: 346
# Scores: (min: 15, avg: 155.85, max: 405)
#
# Run: 495, exploration: 0.1, score: 190
# Scores: (min: 16, avg: 157.6, max: 405)
#
# Run: 496, exploration: 0.1, score: 196
# Scores: (min: 18, avg: 159.4, max: 405)
#
# Run: 497, exploration: 0.1, score: 199
# Scores: (min: 20, avg: 161.21, max: 405)
#
# Run: 498, exploration: 0.1, score: 375
# Scores: (min: 23, avg: 164.76, max: 405)
#
# Run: 499, exploration: 0.1, score: 249
# Scores: (min: 23, avg: 166.94, max: 405)
#
# Run: 500, exploration: 0.1, score: 188
# Scores: (min: 23, avg: 167.84, max: 405)
#
# Run: 501, exploration: 0.1, score: 279
# Scores: (min: 23, avg: 169.9, max: 405)
#
# Run: 502, exploration: 0.1, score: 300
# Scores: (min: 23, avg: 172.35, max: 405)
#
# Run: 503, exploration: 0.1, score: 166
# Scores: (min: 23, avg: 173.67, max: 405)
#
# Run: 504, exploration: 0.1, score: 362
# Scores: (min: 23, avg: 176.65, max: 405)
# Run: 505, exploration: 0.1, score: 187
# Scores: (min: 23, avg: 177.98, max: 405)
#
# Run: 506, exploration: 0.1, score: 134
# Scores: (min: 23, avg: 178.71, max: 405)
#
# Run: 507, exploration: 0.1, score: 185
# Scores: (min: 23, avg: 180, max: 405)
#
# Run: 508, exploration: 0.1, score: 207
# Scores: (min: 23, avg: 181.51, max: 405)
#
# Run: 509, exploration: 0.1, score: 186
# Scores: (min: 23, avg: 182.79, max: 405)
#
# Run: 510, exploration: 0.1, score: 182
# Scores: (min: 23, avg: 183.94, max: 405)
#
# Run: 511, exploration: 0.1, score: 137
# Scores: (min: 23, avg: 184.26, max: 405)
#
# Run: 512, exploration: 0.1, score: 202
# Scores: (min: 23, avg: 185.48, max: 405)
#
# Run: 513, exploration: 0.1, score: 135
# Scores: (min: 23, avg: 185.39, max: 405)
#
# Run: 514, exploration: 0.1, score: 125
# Scores: (min: 23, avg: 184.44, max: 405)
#
# Run: 515, exploration: 0.1, score: 205
# Scores: (min: 23, avg: 184.61, max: 405)
#
# Run: 516, exploration: 0.1, score: 243
# Scores: (min: 23, avg: 182.99, max: 375)
#
# Run: 517, exploration: 0.1, score: 376
# Scores: (min: 23, avg: 185.53, max: 376)
#
# Run: 518, exploration: 0.1, score: 210
# Scores: (min: 23, avg: 185.86, max: 376)
#
# Run: 519, exploration: 0.1, score: 151
# Scores: (min: 23, avg: 186.09, max: 376)
#
# Run: 520, exploration: 0.1, score: 350
# Scores: (min: 23, avg: 189.29, max: 376)
#
# Run: 521, exploration: 0.1, score: 233
# Scores: (min: 23, avg: 190.37, max: 376)
#
# Run: 522, exploration: 0.1, score: 129
# Scores: (min: 23, avg: 189.02, max: 376)
#
# Run: 523, exploration: 0.1, score: 138
# Scores: (min: 23, avg: 188.97, max: 376)
#
# Run: 524, exploration: 0.1, score: 182
# Scores: (min: 23, avg: 188.96, max: 376)
#
# Run: 525, exploration: 0.1, score: 146
# Scores: (min: 23, avg: 189.84, max: 376)
#
# Run: 526, exploration: 0.1, score: 157
# Scores: (min: 23, avg: 190.29, max: 376)
#
# Run: 527, exploration: 0.1, score: 181
# Scores: (min: 23, avg: 190.81, max: 376)
#
# Run: 528, exploration: 0.1, score: 199
# Scores: (min: 23, avg: 191.23, max: 376)
#
# Run: 529, exploration: 0.1, score: 155
# Scores: (min: 23, avg: 191.77, max: 376)
#
# Run: 530, exploration: 0.1, score: 183
# Scores: (min: 23, avg: 192.52, max: 376)
#
# Run: 531, exploration: 0.1, score: 193
# Scores: (min: 23, avg: 193.13, max: 376)
#
# Run: 532, exploration: 0.1, score: 206
# Scores: (min: 23, avg: 193.12, max: 376)
#
# Run: 533, exploration: 0.1, score: 309
# Scores: (min: 23, avg: 194.13, max: 376)
#
# Run: 534, exploration: 0.1, score: 195
# Scores: (min: 23, avg: 192.8, max: 376)
#
# Run: 535, exploration: 0.1, score: 137
# Scores: (min: 23, avg: 191.21, max: 376)
#
# Run: 536, exploration: 0.1, score: 17
# Scores: (min: 17, avg: 190.52, max: 376)
#
# Run: 537, exploration: 0.1, score: 15
# Scores: (min: 15, avg: 188.92, max: 376)
#
# Run: 538, exploration: 0.1, score: 244
# Scores: (min: 15, avg: 189.11, max: 376)
#
# Run: 539, exploration: 0.1, score: 199
# Scores: (min: 15, avg: 189.34, max: 376)
#
# Run: 540, exploration: 0.1, score: 309
# Scores: (min: 15, avg: 191.87, max: 376)
#
# Run: 541, exploration: 0.1, score: 248
# Scores: (min: 15, avg: 194.02, max: 376)
#
# Run: 542, exploration: 0.1, score: 130
# Scores: (min: 15, avg: 194.1, max: 376)
#
# Run: 543, exploration: 0.1, score: 145
# Scores: (min: 15, avg: 192.99, max: 376)
#
# Run: 544, exploration: 0.1, score: 38
# Scores: (min: 15, avg: 192.17, max: 376)
#
# Run: 545, exploration: 0.1, score: 296
# Scores: (min: 15, avg: 193.26, max: 376)
#
# Run: 546, exploration: 0.1, score: 424
# Scores: (min: 15, avg: 196.26, max: 424)
#
# Solved in 446 runs, 546 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-7-c6fe6800ed95> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# The goal of the agent in the cartpole problem is to balance a pole on a cart by applying force to move the cart left or right. The agent attempts to keep the pole upright for as long as possible without it falling over or the cart moving out of the predefined boundaries.
# The state values for the CartPole problem are the cart position, cart velocity, pole angle, and pole angular velocity. In order to cause a change in the state values, the program must take actions on them. The possible actions available are to apply force to move the cart left or apply force to move the cart right.
# This example of reinforcement learning uses the Deep Q-learning algorithm and uses the DQNSolver. This algorithm uses a neural network to approximate the Q-value function, which enables the agent to make decisions in continuous state spaces.
# Experience replay  is used to improve the stability and efficiency of training in reinforcement learning. In the cartpole problem, the agent stores its experiences in a buffer during training. Each experience contains: current state, action taken, reward received, and next state. The discount factor determines the importance of future rewards. The higher the value, or closer to 1, the agent prioritizes long term rewards, which encourages pole balancing. The lower the value, or closer to 0, the agent focuses on immediate reqards, which may result in short term actions that are less optimal for balancing to pole.
# The neural network architecture for solving the cartpole problem consists of an input layer, hidden layers, and an output layer. The input layer takes the state values, passes it to the hidden layer to process the data, and then passes the processed data to the output layer to produce the Q value for each possible action.
# The neural network makes the Q-learning algorithm more efficient by approximating the Q-value function, which allows the agent to observe from its experiences and make better decisions.
# When applying a higher learning rate, it creates faster updates, but leads to instability. Lower learning rates creates slower training and requires more episodes but is more stable.
#
# PyLessons. (n.d.). https://pylessons.com/CartPole-reinforcement-learning
# Chan, M. (2018, June 19). Cart-Pole Balancing with Q-Learning - Matthew Chan - Medium. Medium. https://medium.com/@tuzzer/cart-pole-balancing-with-q-learning-b54c6068d947
#
#
# Please note:
#     example 1: solved in 449 runs, with 549 total runs (base code)
#     example 2: (increased learning rate)ended after approximately 2000 episodes with very low scores, very inefficient solution
#     example 3: solved in 446 runs, with 546 total runs (increased exploration factor)
